# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import *
import cv2
import numpy as np
import random
import os
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\Valid",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\test",
    target_size=(224, 224),
    batch_size=16,
    shuffle=False 
)

print("Train classes:", train_generator.class_indices)
print("Validation classes:", val_generator.class_indices)
print("Test classes:", test_generator.class_indices)
# Out:
# Found 11684 images belonging to 4 classes.
# Found 2939 images belonging to 4 classes.
# Found 2854 images belonging to 4 classes.
# Train classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Validation classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Test classes: {'0': 0, '1': 1, '2': 2, '3': 3}

# %%
def inception_block(x, f1, f3r, f3, f5r, f5, pool_proj):
    path1 = Conv2D(f1, (1,1), padding='same', activation='relu')(x)
    
    path2 = Conv2D(f3r, (1,1), padding='same', activation='relu')(x)
    path2 = Conv2D(f3, (3,3), padding='same', activation='relu')(path2)
    
    path3 = Conv2D(f5r, (1,1), padding='same', activation='relu')(x)
    path3 = Conv2D(f5, (5,5), padding='same', activation='relu')(path3)
    
    path4 = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    path4 = Conv2D(pool_proj, (1,1), padding='same', activation='relu')(path4)
    
    return tf.keras.layers.concatenate([path1, path2, path3, path4], axis=-1)



def GoogLeNet(input_shape=(1024,1024,3), num_classes=4):
    input_layer = Input(shape=input_shape)

    x = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu')(input_layer)
    x = MaxPooling2D((3,3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Conv2D(64, (1,1), activation='relu')(x)
    x = Conv2D(192, (3,3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3,3), strides=(2,2), padding='same')(x)
    
    x = inception_block(x, 64, 96, 128, 16, 32, 32)     
    x = inception_block(x, 128, 128, 192, 32, 96, 64)   
    x = MaxPooling2D((3,3), strides=(2,2), padding='same')(x)
    
    x = inception_block(x, 192, 96, 208, 16, 48, 64)    
    x = inception_block(x, 160, 112, 224, 24, 64, 64)   
    x = inception_block(x, 128, 128, 256, 24, 64, 64)  
    x = inception_block(x, 112, 144, 288, 32, 64, 64)  
    x = inception_block(x, 256, 160, 320, 32, 128, 128) 
    x =MaxPooling2D((3,3), strides=(2,2), padding='same')(x)
    
    x = inception_block(x, 256, 160, 320, 32, 128, 128) 
    x = inception_block(x, 384, 192, 384, 48, 128, 128) 
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)
    output = Dense(num_classes, activation='softmax')(x)

    model =Model(inputs=input_layer, outputs=output)
    return model

model = GoogLeNet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 4160        batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 192 110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 192 768         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 192 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 96) 18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 16) 3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 192 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 32) 12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 32) 6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 128 32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 32) 8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 256 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 128 32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 192 221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 96) 76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 480 0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 224)  226016      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   38464       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 512)  0           conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 256)  295168      conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 64)   38464       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 512)  0           conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 288)  373536      conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 64)   51264       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 528)  0           conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 320)  461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 128)  102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 64, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 832)  0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 832)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 160)  133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 32)   26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 832)  0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 256)  213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 320)  461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 128)  102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 128)  106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 832)  0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 192)  159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 48)   39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 32, 32, 832)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 384)  319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 384)  663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 128)  153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 128)  106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 1024) 0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            4100        dropout[0][0]
# ==================================================================================================
# Total params: 5,978,676
# Trainable params: 5,978,164
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

opt = Adam(learning_rate=0.0001)
model.compile(
    loss='categorical_crossentropy',
    optimizer=opt,
    metrics=['accuracy']
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    mode='min',
    factor=0.5,
    patience=5,
    verbose=1,
    cooldown=1,
    min_delta=0.0001
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=10,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

check_path = '/content/drive/MyDrive/google net D2.weights.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    check_path,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='min'
)

hist_scratch =model.fit(
    train_generator,
    validation_data=val_generator, 
    epochs=30,
    verbose=1,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/30
# 731/731 [==============================] - 100s 127ms/step - loss: 0.7611 - accuracy: 0.6445 - val_loss: 0.7657 - val_accuracy: 0.6509
#
# Epoch 00001: val_loss improved from inf to 0.76567, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 2/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.5509 - accuracy: 0.7497 - val_loss: 2.0233 - val_accuracy: 0.4464
#
# Epoch 00002: val_loss did not improve from 0.76567
# Epoch 3/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.4960 - accuracy: 0.7818 - val_loss: 2.5182 - val_accuracy: 0.4032
#
# Epoch 00003: val_loss did not improve from 0.76567
# Epoch 4/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.4558 - accuracy: 0.8001 - val_loss: 5.3317 - val_accuracy: 0.2392
#
# Epoch 00004: val_loss did not improve from 0.76567
# Epoch 5/30
# 731/731 [==============================] - 41s 57ms/step - loss: 0.4124 - accuracy: 0.8223 - val_loss: 2.7416 - val_accuracy: 0.3467
#
# Epoch 00005: val_loss did not improve from 0.76567
# Epoch 6/30
# 731/731 [==============================] - 42s 58ms/step - loss: 0.3849 - accuracy: 0.8341 - val_loss: 0.7214 - val_accuracy: 0.7312
#
# Epoch 00006: val_loss improved from 0.76567 to 0.72142, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 7/30
# 731/731 [==============================] - 42s 58ms/step - loss: 0.3617 - accuracy: 0.8518 - val_loss: 2.3759 - val_accuracy: 0.4131
#
# Epoch 00007: val_loss did not improve from 0.72142
# Epoch 8/30
# 731/731 [==============================] - 43s 59ms/step - loss: 0.3541 - accuracy: 0.8553 - val_loss: 2.7482 - val_accuracy: 0.5196
#
# Epoch 00008: val_loss did not improve from 0.72142
# Epoch 9/30
# 731/731 [==============================] - 43s 59ms/step - loss: 0.3366 - accuracy: 0.8606 - val_loss: 0.5916 - val_accuracy: 0.7622
#
# Epoch 00009: val_loss improved from 0.72142 to 0.59161, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 10/30
# 731/731 [==============================] - 42s 58ms/step - loss: 0.3195 - accuracy: 0.8681 - val_loss: 2.5389 - val_accuracy: 0.5992
#
# Epoch 00010: val_loss did not improve from 0.59161
# Epoch 11/30
# 731/731 [==============================] - 43s 59ms/step - loss: 0.2995 - accuracy: 0.8789 - val_loss: 1.2235 - val_accuracy: 0.6703
#
# Epoch 00011: val_loss did not improve from 0.59161
# Epoch 12/30
# 731/731 [==============================] - 42s 57ms/step - loss: 0.3071 - accuracy: 0.8744 - val_loss: 2.7455 - val_accuracy: 0.4634
#
# Epoch 00012: val_loss did not improve from 0.59161
# Epoch 13/30
# 731/731 [==============================] - 42s 57ms/step - loss: 0.2808 - accuracy: 0.8808 - val_loss: 0.7958 - val_accuracy: 0.7241
#
# Epoch 00013: val_loss did not improve from 0.59161
# Epoch 14/30
# 731/731 [==============================] - 43s 59ms/step - loss: 0.2806 - accuracy: 0.8851 - val_loss: 3.5782 - val_accuracy: 0.5461
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00014: val_loss did not improve from 0.59161
# Epoch 15/30
# 731/731 [==============================] - 43s 59ms/step - loss: 0.2360 - accuracy: 0.8999 - val_loss: 0.3095 - val_accuracy: 0.8690
#
# Epoch 00015: val_loss improved from 0.59161 to 0.30950, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 16/30
# 731/731 [==============================] - 42s 57ms/step - loss: 0.2193 - accuracy: 0.9093 - val_loss: 0.7804 - val_accuracy: 0.7465
#
# Epoch 00016: val_loss did not improve from 0.30950
# Epoch 17/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.2221 - accuracy: 0.9058 - val_loss: 4.1118 - val_accuracy: 0.4536
#
# Epoch 00017: val_loss did not improve from 0.30950
# Epoch 18/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.2155 - accuracy: 0.9109 - val_loss: 3.6832 - val_accuracy: 0.5434
#
# Epoch 00018: val_loss did not improve from 0.30950
# Epoch 19/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.2119 - accuracy: 0.9119 - val_loss: 0.5729 - val_accuracy: 0.8156
#
# Epoch 00019: val_loss did not improve from 0.30950
# Epoch 20/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.2028 - accuracy: 0.9173 - val_loss: 2.8036 - val_accuracy: 0.5468
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00020: val_loss did not improve from 0.30950
# Epoch 21/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.1791 - accuracy: 0.9253 - val_loss: 0.2544 - val_accuracy: 0.8986
#
# Epoch 00021: val_loss improved from 0.30950 to 0.25436, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 22/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.1700 - accuracy: 0.9320 - val_loss: 0.8490 - val_accuracy: 0.7945
#
# Epoch 00022: val_loss did not improve from 0.25436
# Epoch 23/30
# 731/731 [==============================] - 41s 57ms/step - loss: 0.1669 - accuracy: 0.9305 - val_loss: 0.2878 - val_accuracy: 0.8884
#
# Epoch 00023: val_loss did not improve from 0.25436
# Epoch 24/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.1576 - accuracy: 0.9350 - val_loss: 0.2484 - val_accuracy: 0.9023
#
# Epoch 00024: val_loss improved from 0.25436 to 0.24836, saving model to /content/drive/MyDrive\google net D2.weights.h5
# Epoch 25/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.1554 - accuracy: 0.9353 - val_loss: 0.2820 - val_accuracy: 0.8989
#
# Epoch 00025: val_loss did not improve from 0.24836
# Epoch 26/30
# 731/731 [==============================] - 41s 56ms/step - loss: 0.1536 - accuracy: 0.9364 - val_loss: 0.2704 - val_accuracy: 0.8911
#
# Epoch 00026: val_loss did not improve from 0.24836
# Epoch 27/30
# 731/731 [==============================] - 41s 57ms/step - loss: 0.1506 - accuracy: 0.9409 - val_loss: 0.4937 - val_accuracy: 0.8357
#
# Epoch 00027: val_loss did not improve from 0.24836
# Epoch 28/30
# 731/731 [==============================] - 41s 57ms/step - loss: 0.1486 - accuracy: 0.9380 - val_loss: 0.3479 - val_accuracy: 0.8741
#
# Epoch 00028: val_loss did not improve from 0.24836
# Epoch 29/30
# 731/731 [==============================] - 42s 57ms/step - loss: 0.1453 - accuracy: 0.9403 - val_loss: 0.2867 - val_accuracy: 0.9020
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00029: val_loss did not improve from 0.24836
# Epoch 30/30
# 731/731 [==============================] - 42s 58ms/step - loss: 0.1260 - accuracy: 0.9493 - val_loss: 0.2538 - val_accuracy: 0.9078
#
# Epoch 00030: val_loss did not improve from 0.24836

# %%
print(hist_scratch.history.keys())

import matplotlib.pyplot as plt
f, ax = plt.subplots()
ax.plot(hist_scratch.history['accuracy'])
ax.plot(hist_scratch.history['val_accuracy'], '--')
ax.legend(['Train acc', 'Validation acc'])
ax.set_title('Training/Validation acc per Epoch')
ax.set_xlabel('Epoch')
ax.set_ylabel('acc')

import matplotlib.pyplot as plt
f, ax = plt.subplots()
ax.plot(hist_scratch.history['loss'], )
ax.plot(hist_scratch.history['val_loss'], '--')
ax.legend(['Train Loss', 'Validation Loss'])
ax.set_title('Training/Validation Loss per Epoch')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Text(0, 0.5, 'Loss')

# %%
# vgg16model.load_weights("./cropModel.h5")
class_labels = test_generator.class_indices
oriningal_test_classes = test_generator.labels
print(class_labels)
print("Original test classes")
print(oriningal_test_classes)

Y_pred =model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print("Predicted test classes")
print(y_pred)
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}
# Original test classes
# [0 0 0 ... 3 3 3]
# Predicted test classes
# [0 0 0 ... 3 3 3]

# %%
print('Accuracy {}'.format(accuracy_score(y_true=test_generator.labels, y_pred=y_pred)))
print('F1 {}'.format(f1_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('precision {}'.format(precision_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('recall {}'.format(recall_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))

print('jaccard {}'.format(jaccard_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('classification_report\n {}'.format(classification_report(y_true=test_generator.labels, y_pred=y_pred)))
print('\n\n')
cm = confusion_matrix(y_true=test_generator.labels, y_pred=y_pred)
print(cm)
# Out:
# Accuracy 0.9046951646811493
# F1 0.9056502727504723
# precision 0.9066109801938476
# recall 0.905159151193634
# jaccard 0.8336343672711712
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       754
#            1       0.81      0.84      0.83       700
#            2       0.94      0.90      0.92       700
#            3       0.99      1.00      1.00       700
#
#     accuracy                           0.90      2854
#    macro avg       0.91      0.91      0.91      2854
# weighted avg       0.91      0.90      0.91      2854
#
#
#
#
# [[664  83   7   0]
#  [ 80 590  30   0]
#  [ 10  57 629   4]
#  [  1   0   0 699]]
