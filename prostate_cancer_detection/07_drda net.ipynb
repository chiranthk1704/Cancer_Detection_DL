# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import * 
import cv2
import numpy as np
import random
import os
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\Valid",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\test",
    target_size=(224, 224),
    batch_size=16,
    shuffle=False 
)

print("Train classes:", train_generator.class_indices)
print("Validation classes:", val_generator.class_indices)
print("Test classes:", test_generator.class_indices)
# Out:
# Found 11684 images belonging to 4 classes.
# Found 2939 images belonging to 4 classes.
# Found 2854 images belonging to 4 classes.
# Train classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Validation classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Test classes: {'0': 0, '1': 1, '2': 2, '3': 3}

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
def CALayer(x, channels, reduction=16, name="ca"):

    y = layers.GlobalAveragePooling2D(name=f"{name}_gap")(x)

    y = layers.Dense(
        channels // reduction,
        activation='relu',
        use_bias=True,
        name=f"{name}_fc1"
    )(y)

    y = layers.Dense(
        channels,
        activation='sigmoid',
        use_bias=True,
        name=f"{name}_fc2"
    )(y)

    y = layers.Reshape((1, 1, channels), name=f"{name}_reshape")(y)

    out = layers.Multiply(name=f"{name}_scale")([x, y])

    return out

def channel_shuffle(x, groups):
    batch_size = tf.shape(x)[0]
    height = tf.shape(x)[1]
    width = tf.shape(x)[2]
    channels = x.shape[-1]   

    channels_per_group = channels // groups

    x = tf.reshape(x, [batch_size, height, width, groups, channels_per_group])

    x = tf.transpose(x, [0, 1, 2, 4, 3])

    x = tf.reshape(x, [batch_size, height, width, channels])

    return x
def grouped_conv1x1(x, out_channels, groups, use_bn=True, use_relu=False, name=None):

    x = layers.Conv2D(
        out_channels,
        kernel_size=1,
        strides=1,
        padding='valid',
        groups=groups,
        use_bias=True,
        name=None if name is None else f"{name}_conv"
    )(x)

    if use_bn:
        x = layers.BatchNormalization(name=None if name is None else f"{name}_bn")(x)

    if use_relu:
        x = layers.ReLU(name=None if name is None else f"{name}_relu")(x)

    return x
def Shuffle3x3(x, in_channels, out_channels, groups=3, grouped_conv=True, name="shuffle3x3"):

    bottleneck_channels = out_channels // 4
    first_1x1_groups = groups if grouped_conv else 1

    residual = x

    x = grouped_conv1x1(
        x,
        bottleneck_channels,
        groups=first_1x1_groups,
        use_bn=True,
        use_relu=True,
        name=f"{name}_compress"
    )

    x = layers.Lambda(lambda z: channel_shuffle(z, groups),
                      name=f"{name}_shuffle")(x)

    x = layers.DepthwiseConv2D(
        kernel_size=3,
        strides=1,
        padding='same',
        use_bias=True,
        name=f"{name}_dwconv3x3"
    )(x)

    x = layers.BatchNormalization(name=f"{name}_dw_bn")(x)

    x = grouped_conv1x1(
        x,
        out_channels,
        groups=groups,
        use_bn=True,
        use_relu=False,
        name=f"{name}_expand"
    )

    x = layers.Add(name=f"{name}_add")([x, residual])
    x = layers.ReLU(name=f"{name}_relu")(x)

    return x
def Shuffle5x5(x, in_channels, out_channels, groups=3, grouped_conv=True, name="shuffle5x5"):

    bottleneck_channels = out_channels // 4
    first_1x1_groups = groups if grouped_conv else 1

    residual = x

    x = grouped_conv1x1(
        x,
        bottleneck_channels,
        groups=first_1x1_groups,
        use_bn=True,
        use_relu=True,
        name=f"{name}_compress"
    )

    x = layers.Lambda(lambda z: channel_shuffle(z, groups),
                      name=f"{name}_shuffle")(x)

    x = layers.DepthwiseConv2D(
        kernel_size=3,   
        strides=1,
        padding='same',
        use_bias=True,
        name=f"{name}_dwconv5x5"
    )(x)

    x = layers.BatchNormalization(name=f"{name}_dw_bn")(x)

    x = grouped_conv1x1(
        x,
        out_channels,
        groups=groups,
        use_bn=True,
        use_relu=False,
        name=f"{name}_expand"
    )

    x = layers.Add(name=f"{name}_add")([x, residual])
    x = layers.ReLU(name=f"{name}_relu")(x)

    return x
    
def DRB(x, n_features, groups=4, name="drb"):

    x_3x3 = Shuffle3x3(
        x,
        in_channels=n_features,
        out_channels=n_features,
        groups=groups,
        name=f"{name}_s3"
    )

    x_5x5 = Shuffle5x5(
        x,
        in_channels=n_features,
        out_channels=n_features,
        groups=groups,
        name=f"{name}_s5"
    )

    out = layers.Concatenate(axis=-1, name=f"{name}_concat")([x_3x3, x_5x5])

    out = layers.Conv2D(
        n_features,
        kernel_size=3,
        padding='same',
        use_bias=True,
        name=f"{name}_outconv"
    )(out)

    out = layers.ReLU(max_value=6.0, name=f"{name}_relu6")(out)

    return out


def RDAB(x, n_blocks, n_features, reductions=16, name="rdab"):

    x_msb = x
    for i in range(n_blocks):
        x_msb = DRB(x_msb, n_features, name=f"{name}_drb_{i}")
        if i == n_blocks - 1:
            x_msb = layers.Activation('sigmoid',
                                      name=f"{name}_sigmoid")(x_msb)

    x_ca = CALayer(x, n_features, reductions, name=f"{name}_ca")

    out = layers.Add(name=f"{name}_add")([x_msb, x_ca])
    out = layers.ReLU(name=f"{name}_relu")(out)

    return out

def DRDANet(input_shape=(224, 224, 3), num_blocks=4, num_classes=2):

    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(32, 3, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x1 = layers.MaxPooling2D((2, 2))(x)  
    x2 = RDAB(x1, num_blocks, 32, reductions=16, name="rdab1")
    x2 = layers.Concatenate(axis=-1)([x1, x2])  
    x2 = layers.MaxPooling2D((2, 2))(x2)       

    x3 = RDAB(x2, num_blocks, 64, reductions=16, name="rdab2")
    x3 = layers.Concatenate(axis=-1)([x3, x2]) 

    x1_1 = layers.MaxPooling2D((2, 2))(x1)       
    x3 = layers.Concatenate(axis=-1)([x3, x1_1])  

    x3 = layers.Conv2D(128, 3, padding='same')(x3)
    x3 = layers.BatchNormalization()(x3)
    x3 = layers.ReLU()(x3)
    x3 = layers.MaxPooling2D((2, 2))(x3)         

    x4 = RDAB(x3, num_blocks, 128, reductions=16, name="rdab3")
    x4 = layers.Concatenate(axis=-1)([x4, x3])  

    x2_1 = layers.MaxPooling2D((2, 2))(x2)      
    x4 = layers.Concatenate(axis=-1)([x4, x2_1]) 

    x1_2 = layers.MaxPooling2D((2, 2))(x1_1)   
    x4 = layers.Concatenate(axis=-1)([x4, x1_2]) 

    x4 = layers.Conv2D(256, 3, padding='same')(x4)
    x4 = layers.BatchNormalization()(x4)
    x4 = layers.ReLU()(x4)
    x4 = layers.MaxPooling2D((2, 2))(x4)       

    x5 = RDAB(x4, num_blocks, 256, reductions=16, name="rdab4")
    x5 = layers.Concatenate(axis=-1)([x5, x4])   

    x3_1 = layers.MaxPooling2D((2, 2))(x3)      
    x5 = layers.Concatenate(axis=-1)([x5, x3_1])

    x2_2 = layers.MaxPooling2D((2, 2))(x2_1)   
    x5 = layers.Concatenate(axis=-1)([x5, x2_2]) 

    x1_3 = layers.MaxPooling2D((2, 2))(x1_2)    
    x5 = layers.Concatenate(axis=-1)([x5, x1_3])

    x5 = layers.Conv2D(512, 3, padding='same')(x5)
    x5 = layers.BatchNormalization()(x5)
    x5 = layers.ReLU()(x5)


    out = layers.MaxPooling2D((2, 2))(x5)       
    out = layers.GlobalAveragePooling2D()(out)  
    out = layers.Dense(4, activation='softmax')(out)
    
    model = models.Model(inputs, out, name="DRDANet")
    return model

model = DRDANet()
model.summary()

dummy = tf.random.normal((1, 224, 224, 3))
out = model(dummy)

print(out.shape)
# Out:
# Model: "DRDANet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 224, 224, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           re_lu[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_compress_conv (C (None, 112, 112, 8)  72          max_pooling2d[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_compress_conv (C (None, 112, 112, 8)  72          max_pooling2d[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_0_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_0_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_0_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_0_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_0_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_0_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_dwconv3x3 (Depth (None, None, None, 8 80          rdab1_drb_0_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_dwconv5x5 (Depth (None, None, None, 8 80          rdab1_drb_0_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_0_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_0_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_expand_conv (Con (None, None, None, 3 96          rdab1_drb_0_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_expand_conv (Con (None, None, None, 3 96          rdab1_drb_0_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_0_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_0_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_0_s3_expand_bn[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_0_s5_expand_bn[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s3_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_0_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_s5_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_0_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_concat (Concatenate (None, 112, 112, 64) 0           rdab1_drb_0_s3_relu[0][0]
#                                                                  rdab1_drb_0_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_outconv (Conv2D)    (None, 112, 112, 32) 18464       rdab1_drb_0_concat[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_0_relu6 (ReLU)        (None, 112, 112, 32) 0           rdab1_drb_0_outconv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_1_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_1_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_1_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_1_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_1_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_1_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_dwconv3x3 (Depth (None, None, None, 8 80          rdab1_drb_1_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_dwconv5x5 (Depth (None, None, None, 8 80          rdab1_drb_1_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_1_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_1_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_expand_conv (Con (None, None, None, 3 96          rdab1_drb_1_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_expand_conv (Con (None, None, None, 3 96          rdab1_drb_1_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_1_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_1_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_1_s3_expand_bn[0][0]
#                                                                  rdab1_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_1_s5_expand_bn[0][0]
#                                                                  rdab1_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s3_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_1_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_s5_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_1_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_concat (Concatenate (None, 112, 112, 64) 0           rdab1_drb_1_s3_relu[0][0]
#                                                                  rdab1_drb_1_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_outconv (Conv2D)    (None, 112, 112, 32) 18464       rdab1_drb_1_concat[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_1_relu6 (ReLU)        (None, 112, 112, 32) 0           rdab1_drb_1_outconv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_2_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_2_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_2_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_2_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_2_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_2_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_dwconv3x3 (Depth (None, None, None, 8 80          rdab1_drb_2_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_dwconv5x5 (Depth (None, None, None, 8 80          rdab1_drb_2_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_2_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_2_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_expand_conv (Con (None, None, None, 3 96          rdab1_drb_2_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_expand_conv (Con (None, None, None, 3 96          rdab1_drb_2_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_2_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_2_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_2_s3_expand_bn[0][0]
#                                                                  rdab1_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_2_s5_expand_bn[0][0]
#                                                                  rdab1_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s3_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_2_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_s5_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_2_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_concat (Concatenate (None, 112, 112, 64) 0           rdab1_drb_2_s3_relu[0][0]
#                                                                  rdab1_drb_2_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_outconv (Conv2D)    (None, 112, 112, 32) 18464       rdab1_drb_2_concat[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_2_relu6 (ReLU)        (None, 112, 112, 32) 0           rdab1_drb_2_outconv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_compress_conv (C (None, 112, 112, 8)  72          rdab1_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_3_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_compress_bn (Bat (None, 112, 112, 8)  32          rdab1_drb_3_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_3_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_compress_relu (R (None, 112, 112, 8)  0           rdab1_drb_3_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_3_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_shuffle (Lambda) (None, None, None, 8 0           rdab1_drb_3_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_dwconv3x3 (Depth (None, None, None, 8 80          rdab1_drb_3_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_dwconv5x5 (Depth (None, None, None, 8 80          rdab1_drb_3_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_3_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_dw_bn (BatchNorm (None, None, None, 8 32          rdab1_drb_3_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_expand_conv (Con (None, None, None, 3 96          rdab1_drb_3_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_expand_conv (Con (None, None, None, 3 96          rdab1_drb_3_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_3_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_expand_bn (Batch (None, None, None, 3 128         rdab1_drb_3_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_3_s3_expand_bn[0][0]
#                                                                  rdab1_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_add (Add)        (None, 112, 112, 32) 0           rdab1_drb_3_s5_expand_bn[0][0]
#                                                                  rdab1_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s3_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_3_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_s5_relu (ReLU)      (None, 112, 112, 32) 0           rdab1_drb_3_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab1_ca_gap (GlobalAveragePool (None, 32)           0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_concat (Concatenate (None, 112, 112, 64) 0           rdab1_drb_3_s3_relu[0][0]
#                                                                  rdab1_drb_3_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab1_ca_fc1 (Dense)            (None, 2)            66          rdab1_ca_gap[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_outconv (Conv2D)    (None, 112, 112, 32) 18464       rdab1_drb_3_concat[0][0]
# __________________________________________________________________________________________________
# rdab1_ca_fc2 (Dense)            (None, 32)           96          rdab1_ca_fc1[0][0]
# __________________________________________________________________________________________________
# rdab1_drb_3_relu6 (ReLU)        (None, 112, 112, 32) 0           rdab1_drb_3_outconv[0][0]
# __________________________________________________________________________________________________
# rdab1_ca_reshape (Reshape)      (None, 1, 1, 32)     0           rdab1_ca_fc2[0][0]
# __________________________________________________________________________________________________
# rdab1_sigmoid (Activation)      (None, 112, 112, 32) 0           rdab1_drb_3_relu6[0][0]
# __________________________________________________________________________________________________
# rdab1_ca_scale (Multiply)       (None, 112, 112, 32) 0           max_pooling2d[0][0]
#                                                                  rdab1_ca_reshape[0][0]
# __________________________________________________________________________________________________
# rdab1_add (Add)                 (None, 112, 112, 32) 0           rdab1_sigmoid[0][0]
#                                                                  rdab1_ca_scale[0][0]
# __________________________________________________________________________________________________
# rdab1_relu (ReLU)               (None, 112, 112, 32) 0           rdab1_add[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 112, 112, 64) 0           max_pooling2d[0][0]
#                                                                  rdab1_relu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_compress_conv (C (None, 56, 56, 16)   272         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_compress_conv (C (None, 56, 56, 16)   272         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_0_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_0_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_0_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_0_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_0_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_0_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_dwconv3x3 (Depth (None, None, None, 1 160         rdab2_drb_0_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_dwconv5x5 (Depth (None, None, None, 1 160         rdab2_drb_0_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_0_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_0_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_expand_conv (Con (None, None, None, 6 320         rdab2_drb_0_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_expand_conv (Con (None, None, None, 6 320         rdab2_drb_0_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_0_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_0_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_0_s3_expand_bn[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_0_s5_expand_bn[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s3_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_0_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_s5_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_0_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_concat (Concatenate (None, 56, 56, 128)  0           rdab2_drb_0_s3_relu[0][0]
#                                                                  rdab2_drb_0_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_outconv (Conv2D)    (None, 56, 56, 64)   73792       rdab2_drb_0_concat[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_0_relu6 (ReLU)        (None, 56, 56, 64)   0           rdab2_drb_0_outconv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_1_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_1_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_1_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_1_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_1_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_1_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_dwconv3x3 (Depth (None, None, None, 1 160         rdab2_drb_1_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_dwconv5x5 (Depth (None, None, None, 1 160         rdab2_drb_1_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_1_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_1_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_expand_conv (Con (None, None, None, 6 320         rdab2_drb_1_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_expand_conv (Con (None, None, None, 6 320         rdab2_drb_1_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_1_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_1_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_1_s3_expand_bn[0][0]
#                                                                  rdab2_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_1_s5_expand_bn[0][0]
#                                                                  rdab2_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s3_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_1_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_s5_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_1_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_concat (Concatenate (None, 56, 56, 128)  0           rdab2_drb_1_s3_relu[0][0]
#                                                                  rdab2_drb_1_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_outconv (Conv2D)    (None, 56, 56, 64)   73792       rdab2_drb_1_concat[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_1_relu6 (ReLU)        (None, 56, 56, 64)   0           rdab2_drb_1_outconv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_2_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_2_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_2_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_2_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_2_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_2_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_dwconv3x3 (Depth (None, None, None, 1 160         rdab2_drb_2_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_dwconv5x5 (Depth (None, None, None, 1 160         rdab2_drb_2_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_2_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_2_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_expand_conv (Con (None, None, None, 6 320         rdab2_drb_2_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_expand_conv (Con (None, None, None, 6 320         rdab2_drb_2_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_2_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_2_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_2_s3_expand_bn[0][0]
#                                                                  rdab2_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_2_s5_expand_bn[0][0]
#                                                                  rdab2_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s3_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_2_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_s5_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_2_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_concat (Concatenate (None, 56, 56, 128)  0           rdab2_drb_2_s3_relu[0][0]
#                                                                  rdab2_drb_2_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_outconv (Conv2D)    (None, 56, 56, 64)   73792       rdab2_drb_2_concat[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_2_relu6 (ReLU)        (None, 56, 56, 64)   0           rdab2_drb_2_outconv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_compress_conv (C (None, 56, 56, 16)   272         rdab2_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_3_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_compress_bn (Bat (None, 56, 56, 16)   64          rdab2_drb_3_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_3_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_compress_relu (R (None, 56, 56, 16)   0           rdab2_drb_3_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_3_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_shuffle (Lambda) (None, None, None, 1 0           rdab2_drb_3_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_dwconv3x3 (Depth (None, None, None, 1 160         rdab2_drb_3_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_dwconv5x5 (Depth (None, None, None, 1 160         rdab2_drb_3_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_3_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_dw_bn (BatchNorm (None, None, None, 1 64          rdab2_drb_3_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_expand_conv (Con (None, None, None, 6 320         rdab2_drb_3_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_expand_conv (Con (None, None, None, 6 320         rdab2_drb_3_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_3_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_expand_bn (Batch (None, None, None, 6 256         rdab2_drb_3_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_3_s3_expand_bn[0][0]
#                                                                  rdab2_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_add (Add)        (None, 56, 56, 64)   0           rdab2_drb_3_s5_expand_bn[0][0]
#                                                                  rdab2_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s3_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_3_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_s5_relu (ReLU)      (None, 56, 56, 64)   0           rdab2_drb_3_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab2_ca_gap (GlobalAveragePool (None, 64)           0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_concat (Concatenate (None, 56, 56, 128)  0           rdab2_drb_3_s3_relu[0][0]
#                                                                  rdab2_drb_3_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab2_ca_fc1 (Dense)            (None, 4)            260         rdab2_ca_gap[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_outconv (Conv2D)    (None, 56, 56, 64)   73792       rdab2_drb_3_concat[0][0]
# __________________________________________________________________________________________________
# rdab2_ca_fc2 (Dense)            (None, 64)           320         rdab2_ca_fc1[0][0]
# __________________________________________________________________________________________________
# rdab2_drb_3_relu6 (ReLU)        (None, 56, 56, 64)   0           rdab2_drb_3_outconv[0][0]
# __________________________________________________________________________________________________
# rdab2_ca_reshape (Reshape)      (None, 1, 1, 64)     0           rdab2_ca_fc2[0][0]
# __________________________________________________________________________________________________
# rdab2_sigmoid (Activation)      (None, 56, 56, 64)   0           rdab2_drb_3_relu6[0][0]
# __________________________________________________________________________________________________
# rdab2_ca_scale (Multiply)       (None, 56, 56, 64)   0           max_pooling2d_1[0][0]
#                                                                  rdab2_ca_reshape[0][0]
# __________________________________________________________________________________________________
# rdab2_add (Add)                 (None, 56, 56, 64)   0           rdab2_sigmoid[0][0]
#                                                                  rdab2_ca_scale[0][0]
# __________________________________________________________________________________________________
# rdab2_relu (ReLU)               (None, 56, 56, 64)   0           rdab2_add[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           rdab2_relu[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 160)  0           concatenate_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 128)  184448      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 56, 56, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_compress_conv (C (None, 28, 28, 32)   1056        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s5_compress_conv (C (None, 28, 28, 32)   1056        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_compress_bn (Bat (None, 28, 28, 32)   128         rdab3_drb_0_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab3_drb_0_s5_compress_bn (Bat (None, 28, 28, 32)   128         rdab3_drb_0_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_compress_relu (R (None, 28, 28, 32)   0           rdab3_drb_0_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s5_compress_relu (R (None, 28, 28, 32)   0           rdab3_drb_0_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_shuffle (Lambda) (None, None, None, 3 0           rdab3_drb_0_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab3_drb_0_s5_shuffle (Lambda) (None, None, None, 3 0           rdab3_drb_0_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_dwconv3x3 (Depth (None, None, None, 3 320         rdab3_drb_0_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s5_dwconv5x5 (Depth (None, None, None, 3 320         rdab3_drb_0_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab3_drb_0_s3_dw_bn (BatchNorm (None, None, None, 3 128         rdab3_drb_0_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  rdab4_drb_0_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_1_s3_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_1_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_1_s5_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_1_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_1_concat (Concatenate (None, 14, 14, 512)  0           rdab4_drb_1_s3_relu[0][0]
#                                                                  rdab4_drb_1_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_1_outconv (Conv2D)    (None, 14, 14, 256)  1179904     rdab4_drb_1_concat[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_1_relu6 (ReLU)        (None, 14, 14, 256)  0           rdab4_drb_1_outconv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_compress_conv (C (None, 14, 14, 64)   4160        rdab4_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_compress_conv (C (None, 14, 14, 64)   4160        rdab4_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_compress_bn (Bat (None, 14, 14, 64)   256         rdab4_drb_2_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_compress_bn (Bat (None, 14, 14, 64)   256         rdab4_drb_2_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_compress_relu (R (None, 14, 14, 64)   0           rdab4_drb_2_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_compress_relu (R (None, 14, 14, 64)   0           rdab4_drb_2_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_shuffle (Lambda) (None, None, None, 6 0           rdab4_drb_2_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_shuffle (Lambda) (None, None, None, 6 0           rdab4_drb_2_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_dwconv3x3 (Depth (None, None, None, 6 640         rdab4_drb_2_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_dwconv5x5 (Depth (None, None, None, 6 640         rdab4_drb_2_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_dw_bn (BatchNorm (None, None, None, 6 256         rdab4_drb_2_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_dw_bn (BatchNorm (None, None, None, 6 256         rdab4_drb_2_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_expand_conv (Con (None, None, None, 2 4352        rdab4_drb_2_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_expand_conv (Con (None, None, None, 2 4352        rdab4_drb_2_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_expand_bn (Batch (None, None, None, 2 1024        rdab4_drb_2_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_expand_bn (Batch (None, None, None, 2 1024        rdab4_drb_2_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_add (Add)        (None, 14, 14, 256)  0           rdab4_drb_2_s3_expand_bn[0][0]
#                                                                  rdab4_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_add (Add)        (None, 14, 14, 256)  0           rdab4_drb_2_s5_expand_bn[0][0]
#                                                                  rdab4_drb_1_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s3_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_2_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_s5_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_2_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_concat (Concatenate (None, 14, 14, 512)  0           rdab4_drb_2_s3_relu[0][0]
#                                                                  rdab4_drb_2_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_outconv (Conv2D)    (None, 14, 14, 256)  1179904     rdab4_drb_2_concat[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_2_relu6 (ReLU)        (None, 14, 14, 256)  0           rdab4_drb_2_outconv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_compress_conv (C (None, 14, 14, 64)   4160        rdab4_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_compress_conv (C (None, 14, 14, 64)   4160        rdab4_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_compress_bn (Bat (None, 14, 14, 64)   256         rdab4_drb_3_s3_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_compress_bn (Bat (None, 14, 14, 64)   256         rdab4_drb_3_s5_compress_conv[0][0
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_compress_relu (R (None, 14, 14, 64)   0           rdab4_drb_3_s3_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_compress_relu (R (None, 14, 14, 64)   0           rdab4_drb_3_s5_compress_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_shuffle (Lambda) (None, None, None, 6 0           rdab4_drb_3_s3_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_shuffle (Lambda) (None, None, None, 6 0           rdab4_drb_3_s5_compress_relu[0][0
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_dwconv3x3 (Depth (None, None, None, 6 640         rdab4_drb_3_s3_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_dwconv5x5 (Depth (None, None, None, 6 640         rdab4_drb_3_s5_shuffle[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_dw_bn (BatchNorm (None, None, None, 6 256         rdab4_drb_3_s3_dwconv3x3[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_dw_bn (BatchNorm (None, None, None, 6 256         rdab4_drb_3_s5_dwconv5x5[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_expand_conv (Con (None, None, None, 2 4352        rdab4_drb_3_s3_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_expand_conv (Con (None, None, None, 2 4352        rdab4_drb_3_s5_dw_bn[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_expand_bn (Batch (None, None, None, 2 1024        rdab4_drb_3_s3_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_expand_bn (Batch (None, None, None, 2 1024        rdab4_drb_3_s5_expand_conv[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_add (Add)        (None, 14, 14, 256)  0           rdab4_drb_3_s3_expand_bn[0][0]
#                                                                  rdab4_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_add (Add)        (None, 14, 14, 256)  0           rdab4_drb_3_s5_expand_bn[0][0]
#                                                                  rdab4_drb_2_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s3_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_3_s3_add[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_s5_relu (ReLU)      (None, 14, 14, 256)  0           rdab4_drb_3_s5_add[0][0]
# __________________________________________________________________________________________________
# rdab4_ca_gap (GlobalAveragePool (None, 256)          0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_concat (Concatenate (None, 14, 14, 512)  0           rdab4_drb_3_s3_relu[0][0]
#                                                                  rdab4_drb_3_s5_relu[0][0]
# __________________________________________________________________________________________________
# rdab4_ca_fc1 (Dense)            (None, 16)           4112        rdab4_ca_gap[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_outconv (Conv2D)    (None, 14, 14, 256)  1179904     rdab4_drb_3_concat[0][0]
# __________________________________________________________________________________________________
# rdab4_ca_fc2 (Dense)            (None, 256)          4352        rdab4_ca_fc1[0][0]
# __________________________________________________________________________________________________
# rdab4_drb_3_relu6 (ReLU)        (None, 14, 14, 256)  0           rdab4_drb_3_outconv[0][0]
# __________________________________________________________________________________________________
# rdab4_ca_reshape (Reshape)      (None, 1, 1, 256)    0           rdab4_ca_fc2[0][0]
# __________________________________________________________________________________________________
# rdab4_sigmoid (Activation)      (None, 14, 14, 256)  0           rdab4_drb_3_relu6[0][0]
# __________________________________________________________________________________________________
# rdab4_ca_scale (Multiply)       (None, 14, 14, 256)  0           max_pooling2d_6[0][0]
#                                                                  rdab4_ca_reshape[0][0]
# __________________________________________________________________________________________________
# rdab4_add (Add)                 (None, 14, 14, 256)  0           rdab4_sigmoid[0][0]
#                                                                  rdab4_ca_scale[0][0]
# __________________________________________________________________________________________________
# rdab4_relu (ReLU)               (None, 14, 14, 256)  0           rdab4_add[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 512)  0           rdab4_relu[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 14, 14, 640)  0           concatenate_6[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 64)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 14, 14, 704)  0           concatenate_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 14, 14, 736)  0           concatenate_8[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 512)  3392000     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 14, 14, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 512)    0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            2052        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 10,799,042
# Trainable params: 10,785,666
# Non-trainable params: 13,376
# __________________________________________________________________________________________________
# (1, 4)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy']
)
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = val_generator.samples // val_generator.batch_size
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='drdanet_best.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]
history = model.fit(
    train_generator,
    epochs=65,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/65
# 730/730 [==============================] - 276s 362ms/step - loss: 0.6628 - accuracy: 0.7059 - val_loss: 0.8893 - val_accuracy: 0.6352
#
# Epoch 00001: val_accuracy improved from -inf to 0.63525, saving model to drdanet_best.h5
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/65
# 730/730 [==============================] - 253s 346ms/step - loss: 0.5134 - accuracy: 0.7713 - val_loss: 0.7225 - val_accuracy: 0.7107
#
# Epoch 00002: val_accuracy improved from 0.63525 to 0.71072, saving model to drdanet_best.h5
# Epoch 3/65
# 730/730 [==============================] - 253s 346ms/step - loss: 0.4702 - accuracy: 0.7928 - val_loss: 1.2604 - val_accuracy: 0.6489
#
# Epoch 00003: val_accuracy did not improve from 0.71072
# Epoch 4/65
# 730/730 [==============================] - 253s 346ms/step - loss: 0.4352 - accuracy: 0.8094 - val_loss: 1.1857 - val_accuracy: 0.5772
#
# Epoch 00004: val_accuracy did not improve from 0.71072
# Epoch 5/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.4087 - accuracy: 0.8215 - val_loss: 0.6782 - val_accuracy: 0.7592
#
# Epoch 00005: val_accuracy improved from 0.71072 to 0.75922, saving model to drdanet_best.h5
# Epoch 6/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3939 - accuracy: 0.8299 - val_loss: 1.2385 - val_accuracy: 0.6335
#
# Epoch 00006: val_accuracy did not improve from 0.75922
# Epoch 7/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3748 - accuracy: 0.8433 - val_loss: 0.5360 - val_accuracy: 0.7865
#
# Epoch 00007: val_accuracy improved from 0.75922 to 0.78654, saving model to drdanet_best.h5
# Epoch 8/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3570 - accuracy: 0.8447 - val_loss: 0.6321 - val_accuracy: 0.7732
#
# Epoch 00008: val_accuracy did not improve from 0.78654
# Epoch 9/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3374 - accuracy: 0.8579 - val_loss: 0.7863 - val_accuracy: 0.7073
#
# Epoch 00009: val_accuracy did not improve from 0.78654
# Epoch 10/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3215 - accuracy: 0.8629 - val_loss: 0.4066 - val_accuracy: 0.8221
#
# Epoch 00010: val_accuracy improved from 0.78654 to 0.82206, saving model to drdanet_best.h5
# Epoch 11/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3220 - accuracy: 0.8643 - val_loss: 0.8352 - val_accuracy: 0.7128
#
# Epoch 00011: val_accuracy did not improve from 0.82206
# Epoch 12/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.3015 - accuracy: 0.8735 - val_loss: 0.4485 - val_accuracy: 0.8145
#
# Epoch 00012: val_accuracy did not improve from 0.82206
# Epoch 13/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2979 - accuracy: 0.8770 - val_loss: 0.3588 - val_accuracy: 0.8504
#
# Epoch 00013: val_accuracy improved from 0.82206 to 0.85041, saving model to drdanet_best.h5
# Epoch 14/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2881 - accuracy: 0.8810 - val_loss: 0.4151 - val_accuracy: 0.8299
#
# Epoch 00014: val_accuracy did not improve from 0.85041
# Epoch 15/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2761 - accuracy: 0.8844 - val_loss: 3.0722 - val_accuracy: 0.4577
#
# Epoch 00015: val_accuracy did not improve from 0.85041
# Epoch 16/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2741 - accuracy: 0.8858 - val_loss: 0.3920 - val_accuracy: 0.8354
#
# Epoch 00016: val_accuracy did not improve from 0.85041
# Epoch 17/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2663 - accuracy: 0.8891 - val_loss: 0.3278 - val_accuracy: 0.8637
#
# Epoch 00017: val_accuracy improved from 0.85041 to 0.86373, saving model to drdanet_best.h5
# Epoch 18/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2646 - accuracy: 0.8891 - val_loss: 0.3295 - val_accuracy: 0.8634
#
# Epoch 00018: val_accuracy did not improve from 0.86373
# Epoch 19/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2551 - accuracy: 0.8961 - val_loss: 0.6195 - val_accuracy: 0.7708
#
# Epoch 00019: val_accuracy did not improve from 0.86373
# Epoch 20/65
# 730/730 [==============================] - 251s 344ms/step - loss: 0.2475 - accuracy: 0.8975 - val_loss: 1.4730 - val_accuracy: 0.5645
#
# Epoch 00020: val_accuracy did not improve from 0.86373
# Epoch 21/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2383 - accuracy: 0.9019 - val_loss: 0.7547 - val_accuracy: 0.7565
#
# Epoch 00021: val_accuracy did not improve from 0.86373
# Epoch 22/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2416 - accuracy: 0.9035 - val_loss: 0.2879 - val_accuracy: 0.8723
#
# Epoch 00022: val_accuracy improved from 0.86373 to 0.87227, saving model to drdanet_best.h5
# Epoch 23/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2397 - accuracy: 0.9013 - val_loss: 0.4554 - val_accuracy: 0.8139
#
# Epoch 00023: val_accuracy did not improve from 0.87227
# Epoch 24/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2371 - accuracy: 0.9034 - val_loss: 0.3677 - val_accuracy: 0.8473
#
# Epoch 00024: val_accuracy did not improve from 0.87227
# Epoch 25/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2319 - accuracy: 0.9079 - val_loss: 0.6953 - val_accuracy: 0.7736
#
# Epoch 00025: val_accuracy did not improve from 0.87227
# Epoch 26/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2233 - accuracy: 0.9090 - val_loss: 0.3288 - val_accuracy: 0.8610
#
# Epoch 00026: val_accuracy did not improve from 0.87227
# Epoch 27/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.2216 - accuracy: 0.9092 - val_loss: 0.3723 - val_accuracy: 0.8487
#
# Epoch 00027: val_accuracy did not improve from 0.87227
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 28/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1901 - accuracy: 0.9240 - val_loss: 0.2087 - val_accuracy: 0.9136
#
# Epoch 00028: val_accuracy improved from 0.87227 to 0.91359, saving model to drdanet_best.h5
# Epoch 29/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1810 - accuracy: 0.9278 - val_loss: 0.2457 - val_accuracy: 0.8924
#
# Epoch 00029: val_accuracy did not improve from 0.91359
# Epoch 30/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1784 - accuracy: 0.9299 - val_loss: 0.2131 - val_accuracy: 0.9160
#
# Epoch 00030: val_accuracy improved from 0.91359 to 0.91598, saving model to drdanet_best.h5
# Epoch 31/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1716 - accuracy: 0.9306 - val_loss: 0.3054 - val_accuracy: 0.8808
#
# Epoch 00031: val_accuracy did not improve from 0.91598
# Epoch 32/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1711 - accuracy: 0.9315 - val_loss: 0.2747 - val_accuracy: 0.8870
#
# Epoch 00032: val_accuracy did not improve from 0.91598
# Epoch 33/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1681 - accuracy: 0.9350 - val_loss: 0.3180 - val_accuracy: 0.8671
#
# Epoch 00033: val_accuracy did not improve from 0.91598
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 34/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1543 - accuracy: 0.9397 - val_loss: 0.1890 - val_accuracy: 0.9273
#
# Epoch 00034: val_accuracy improved from 0.91598 to 0.92725, saving model to drdanet_best.h5
# Epoch 35/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1495 - accuracy: 0.9439 - val_loss: 0.1897 - val_accuracy: 0.9273
#
# Epoch 00035: val_accuracy did not improve from 0.92725
# Epoch 36/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1521 - accuracy: 0.9392 - val_loss: 0.2137 - val_accuracy: 0.9143
#
# Epoch 00036: val_accuracy did not improve from 0.92725
# Epoch 37/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1456 - accuracy: 0.9451 - val_loss: 0.2057 - val_accuracy: 0.9160
#
# Epoch 00037: val_accuracy did not improve from 0.92725
# Epoch 38/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1488 - accuracy: 0.9435 - val_loss: 0.1904 - val_accuracy: 0.9266
#
# Epoch 00038: val_accuracy did not improve from 0.92725
# Epoch 39/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1449 - accuracy: 0.9445 - val_loss: 0.1875 - val_accuracy: 0.9266
#
# Epoch 00039: val_accuracy did not improve from 0.92725
# Epoch 40/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1437 - accuracy: 0.9467 - val_loss: 0.1872 - val_accuracy: 0.9255
#
# Epoch 00040: val_accuracy did not improve from 0.92725
# Epoch 41/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1452 - accuracy: 0.9426 - val_loss: 0.2059 - val_accuracy: 0.9204
#
# Epoch 00041: val_accuracy did not improve from 0.92725
# Epoch 42/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1427 - accuracy: 0.9447 - val_loss: 0.1940 - val_accuracy: 0.9221
#
# Epoch 00042: val_accuracy did not improve from 0.92725
# Epoch 43/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1417 - accuracy: 0.9467 - val_loss: 0.2009 - val_accuracy: 0.9173
#
# Epoch 00043: val_accuracy did not improve from 0.92725
# Epoch 44/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1416 - accuracy: 0.9465 - val_loss: 0.1960 - val_accuracy: 0.9225
#
# Epoch 00044: val_accuracy did not improve from 0.92725
# Epoch 45/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1382 - accuracy: 0.9478 - val_loss: 0.2013 - val_accuracy: 0.9214
#
# Epoch 00045: val_accuracy did not improve from 0.92725
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 46/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1319 - accuracy: 0.9504 - val_loss: 0.1817 - val_accuracy: 0.9259
#
# Epoch 00046: val_accuracy did not improve from 0.92725
# Epoch 47/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1341 - accuracy: 0.9494 - val_loss: 0.1816 - val_accuracy: 0.9290
#
# Epoch 00047: val_accuracy improved from 0.92725 to 0.92896, saving model to drdanet_best.h5
# Epoch 48/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1327 - accuracy: 0.9498 - val_loss: 0.1801 - val_accuracy: 0.9279
#
# Epoch 00048: val_accuracy did not improve from 0.92896
# Epoch 49/65
# 730/730 [==============================] - 259s 355ms/step - loss: 0.1297 - accuracy: 0.9521 - val_loss: 0.1804 - val_accuracy: 0.9245
#
# Epoch 00049: val_accuracy did not improve from 0.92896
# Epoch 50/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1347 - accuracy: 0.9490 - val_loss: 0.1832 - val_accuracy: 0.9232
#
# Epoch 00050: val_accuracy did not improve from 0.92896
# Epoch 51/65
# 730/730 [==============================] - 251s 344ms/step - loss: 0.1313 - accuracy: 0.9504 - val_loss: 0.1825 - val_accuracy: 0.9262
#
# Epoch 00051: val_accuracy did not improve from 0.92896
# Epoch 52/65
# 730/730 [==============================] - 251s 344ms/step - loss: 0.1324 - accuracy: 0.9514 - val_loss: 0.1840 - val_accuracy: 0.9259
#
# Epoch 00052: val_accuracy did not improve from 0.92896
# Epoch 53/65
# 730/730 [==============================] - 251s 344ms/step - loss: 0.1303 - accuracy: 0.9501 - val_loss: 0.1860 - val_accuracy: 0.9235
#
# Epoch 00053: val_accuracy did not improve from 0.92896
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 54/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1294 - accuracy: 0.9533 - val_loss: 0.1800 - val_accuracy: 0.9273
#
# Epoch 00054: val_accuracy did not improve from 0.92896
# Epoch 55/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1273 - accuracy: 0.9505 - val_loss: 0.1798 - val_accuracy: 0.9245
#
# Epoch 00055: val_accuracy did not improve from 0.92896
# Epoch 56/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1249 - accuracy: 0.9555 - val_loss: 0.1795 - val_accuracy: 0.9259
#
# Epoch 00056: val_accuracy did not improve from 0.92896
# Epoch 57/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1270 - accuracy: 0.9513 - val_loss: 0.1802 - val_accuracy: 0.9262
#
# Epoch 00057: val_accuracy did not improve from 0.92896
# Epoch 58/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1288 - accuracy: 0.9511 - val_loss: 0.1798 - val_accuracy: 0.9255
#
# Epoch 00058: val_accuracy did not improve from 0.92896
# Epoch 59/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1259 - accuracy: 0.9530 - val_loss: 0.1795 - val_accuracy: 0.9249
#
# Epoch 00059: val_accuracy did not improve from 0.92896
# Epoch 60/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1269 - accuracy: 0.9517 - val_loss: 0.1797 - val_accuracy: 0.9255
#
# Epoch 00060: val_accuracy did not improve from 0.92896
# Epoch 61/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1247 - accuracy: 0.9542 - val_loss: 0.1791 - val_accuracy: 0.9259
#
# Epoch 00061: val_accuracy did not improve from 0.92896
# Epoch 62/65
# 730/730 [==============================] - 252s 346ms/step - loss: 0.1270 - accuracy: 0.9536 - val_loss: 0.1798 - val_accuracy: 0.9266
#
# Epoch 00062: val_accuracy did not improve from 0.92896
# Epoch 63/65
# 730/730 [==============================] - 254s 347ms/step - loss: 0.1272 - accuracy: 0.9518 - val_loss: 0.1799 - val_accuracy: 0.9255
#
# Epoch 00063: val_accuracy did not improve from 0.92896
# Epoch 64/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1282 - accuracy: 0.9513 - val_loss: 0.1788 - val_accuracy: 0.9276
#
# Epoch 00064: val_accuracy did not improve from 0.92896
# Epoch 65/65
# 730/730 [==============================] - 252s 345ms/step - loss: 0.1290 - accuracy: 0.9513 - val_loss: 0.1791 - val_accuracy: 0.9266
#
# Epoch 00065: val_accuracy did not improve from 0.92896

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'], '--')
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.title('Training / Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'], '--')
plt.legend(['Train Loss', 'Validation Loss'])
plt.title('Training / Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# vgg16model.load_weights("./cropModel.h5")
class_labels = test_generator.class_indices
oriningal_test_classes = test_generator.labels
print(class_labels)
print("Original test classes")
print(oriningal_test_classes)

Y_pred =model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print("Predicted test classes")
print(y_pred)
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}
# Original test classes
# [0 0 0 ... 3 3 3]
# Predicted test classes
# [0 0 0 ... 3 3 3]

# %%
print('Accuracy {}'.format(accuracy_score(y_true=test_generator.labels, y_pred=y_pred)))
print('F1 {}'.format(f1_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('precision {}'.format(precision_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('recall {}'.format(recall_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))

print('jaccard {}'.format(jaccard_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('classification_report\n {}'.format(classification_report(y_true=test_generator.labels, y_pred=y_pred)))
print('\n\n')
cm = confusion_matrix(y_true=test_generator.labels, y_pred=y_pred)
print(cm)
# Out:
# Accuracy 0.9239663629992992
# F1 0.9242083591518646
# precision 0.9250019739148362
# recall 0.923957938613111
# jaccard 0.863431656063235
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       754
#            1       0.88      0.84      0.86       700
#            2       0.94      0.93      0.94       700
#            3       1.00      1.00      1.00       700
#
#     accuracy                           0.92      2854
#    macro avg       0.93      0.92      0.92      2854
# weighted avg       0.92      0.92      0.92      2854
#
#
#
#
# [[697  46  11   0]
#  [ 84 587  29   0]
#  [ 12  34 654   0]
#  [  0   0   1 699]]
