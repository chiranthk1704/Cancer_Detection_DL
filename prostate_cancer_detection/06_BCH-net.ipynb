# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import *
import cv2
import numpy as np
import random
import os
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\Valid",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\test",
    target_size=(256, 256),
    batch_size=16,
    shuffle=False  
)


def bchisto_wrapper(generator):
    while True:
        X, y = next(generator)

        yield (
            {'global_input': X, 'local_input': X},  
            {
                'main_output': y,
                'global_output': y,
                'local_output': y
            }
        )
train_gen = bchisto_wrapper(train_generator)
val_gen   = bchisto_wrapper(val_generator)
test_gen= bchisto_wrapper(test_generator)
print("Train classes:", train_gen)
print("Validation classes:", val_gen)
print("Test classes:", test_gen)
# Out:
# Found 11684 images belonging to 4 classes.
# Found 2939 images belonging to 4 classes.
# Found 2854 images belonging to 4 classes.
# Train classes: <generator object bchisto_wrapper at 0x00000228F67B6580>
# Validation classes: <generator object bchisto_wrapper at 0x00000228F6809A50>
# Test classes: <generator object bchisto_wrapper at 0x00000228F6809190>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input

def inception_module(x):

    conv1 = layers.Conv2D(64, (1, 1), padding="same", activation="relu")(x)
    conv3 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(x)
    conv5 = layers.Conv2D(64, (5, 5), padding="same", activation="relu")(x)

    pool = layers.MaxPooling2D((3, 3), strides=(1, 1), padding="same")(x)
    pool_conv = layers.Conv2D(64, (1, 1), padding="same", activation="relu")(pool)

    return layers.Concatenate(axis=-1)([conv1, conv3, conv5])

def build_feature_extractor(input_tensor, name_prefix):
    """Identical for both Global and Local branches [cite: 178]"""
    x = inception_module(input_tensor)
    
    x = layers.Conv2D(128, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
        
    x = layers.Conv2D(256, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    
    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    return x

def build_bchisto_net(input_shape=(256, 256, 3)):

    img_global = Input(shape=input_shape, name="global_input")
    img_local = Input(shape=input_shape, name="local_input")


    feat_global = build_feature_extractor(img_global, "global")
    gap_global = layers.GlobalAveragePooling2D()(feat_global)
    aux_global = layers.Dense(4, activation='sigmoid', name='global_output')(gap_global)

    feat_local = build_feature_extractor(img_local, "local")
    gap_local = layers.GlobalAveragePooling2D()(feat_local)
    aux_local = layers.Dense(4, activation='sigmoid', name='local_output')(gap_local)


    f_g = layers.GlobalAveragePooling2D()(feat_global)
    f_l = layers.GlobalAveragePooling2D()(feat_local)
    f_ag = layers.Add()([f_g, f_l])


    x = layers.Dense(4024, activation='elu')(f_ag)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(4024, activation='elu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    main_output = layers.Dense(4, activation='sigmoid', name='main_output')(x)

    model = models.Model(inputs=[img_global, img_local], 
                         outputs=[main_output, aux_global, aux_local])
    return model

model = build_bchisto_net()
model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# global_input (InputLayer)       [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# local_input (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_422 (Conv2D)             (None, 256, 256, 64) 256         global_input[0][0]
# __________________________________________________________________________________________________
# conv2d_423 (Conv2D)             (None, 256, 256, 64) 1792        global_input[0][0]
# __________________________________________________________________________________________________
# conv2d_424 (Conv2D)             (None, 256, 256, 64) 4864        global_input[0][0]
# __________________________________________________________________________________________________
# conv2d_437 (Conv2D)             (None, 256, 256, 64) 256         local_input[0][0]
# __________________________________________________________________________________________________
# conv2d_438 (Conv2D)             (None, 256, 256, 64) 1792        local_input[0][0]
# __________________________________________________________________________________________________
# conv2d_439 (Conv2D)             (None, 256, 256, 64) 4864        local_input[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 256, 256, 192 0           conv2d_422[0][0]
#                                                                  conv2d_423[0][0]
#                                                                  conv2d_424[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 256, 256, 192 0           conv2d_437[0][0]
#                                                                  conv2d_438[0][0]
#                                                                  conv2d_439[0][0]
# __________________________________________________________________________________________________
# conv2d_426 (Conv2D)             (None, 256, 256, 128 221312      concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_441 (Conv2D)             (None, 256, 256, 128 221312      concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_324 (BatchN (None, 256, 256, 128 512         conv2d_426[0][0]
# __________________________________________________________________________________________________
# batch_normalization_335 (BatchN (None, 256, 256, 128 512         conv2d_441[0][0]
# __________________________________________________________________________________________________
# conv2d_427 (Conv2D)             (None, 256, 256, 128 147584      batch_normalization_324[0][0]
# __________________________________________________________________________________________________
# conv2d_442 (Conv2D)             (None, 256, 256, 128 147584      batch_normalization_335[0][0]
# __________________________________________________________________________________________________
# batch_normalization_325 (BatchN (None, 256, 256, 128 512         conv2d_427[0][0]
# __________________________________________________________________________________________________
# batch_normalization_336 (BatchN (None, 256, 256, 128 512         conv2d_442[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_169 (MaxPooling2D (None, 128, 128, 128 0           batch_normalization_325[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_175 (MaxPooling2D (None, 128, 128, 128 0           batch_normalization_336[0][0]
# __________________________________________________________________________________________________
# conv2d_428 (Conv2D)             (None, 128, 128, 256 295168      max_pooling2d_169[0][0]
# __________________________________________________________________________________________________
# conv2d_443 (Conv2D)             (None, 128, 128, 256 295168      max_pooling2d_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_326 (BatchN (None, 128, 128, 256 1024        conv2d_428[0][0]
# __________________________________________________________________________________________________
# batch_normalization_337 (BatchN (None, 128, 128, 256 1024        conv2d_443[0][0]
# __________________________________________________________________________________________________
# conv2d_429 (Conv2D)             (None, 128, 128, 256 590080      batch_normalization_326[0][0]
# __________________________________________________________________________________________________
# conv2d_444 (Conv2D)             (None, 128, 128, 256 590080      batch_normalization_337[0][0]
# __________________________________________________________________________________________________
# batch_normalization_327 (BatchN (None, 128, 128, 256 1024        conv2d_429[0][0]
# __________________________________________________________________________________________________
# batch_normalization_338 (BatchN (None, 128, 128, 256 1024        conv2d_444[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_170 (MaxPooling2D (None, 64, 64, 256)  0           batch_normalization_327[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_176 (MaxPooling2D (None, 64, 64, 256)  0           batch_normalization_338[0][0]
# __________________________________________________________________________________________________
# conv2d_430 (Conv2D)             (None, 64, 64, 512)  1180160     max_pooling2d_170[0][0]
# __________________________________________________________________________________________________
# conv2d_445 (Conv2D)             (None, 64, 64, 512)  1180160     max_pooling2d_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_328 (BatchN (None, 64, 64, 512)  2048        conv2d_430[0][0]
# __________________________________________________________________________________________________
# batch_normalization_339 (BatchN (None, 64, 64, 512)  2048        conv2d_445[0][0]
# __________________________________________________________________________________________________
# conv2d_431 (Conv2D)             (None, 64, 64, 512)  2359808     batch_normalization_328[0][0]
# __________________________________________________________________________________________________
# conv2d_446 (Conv2D)             (None, 64, 64, 512)  2359808     batch_normalization_339[0][0]
# __________________________________________________________________________________________________
# batch_normalization_329 (BatchN (None, 64, 64, 512)  2048        conv2d_431[0][0]
# __________________________________________________________________________________________________
# batch_normalization_340 (BatchN (None, 64, 64, 512)  2048        conv2d_446[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_171 (MaxPooling2D (None, 32, 32, 512)  0           batch_normalization_329[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_177 (MaxPooling2D (None, 32, 32, 512)  0           batch_normalization_340[0][0]
# __________________________________________________________________________________________________
# conv2d_432 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_171[0][0]
# __________________________________________________________________________________________________
# conv2d_447 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_330 (BatchN (None, 32, 32, 512)  2048        conv2d_432[0][0]
# __________________________________________________________________________________________________
# batch_normalization_341 (BatchN (None, 32, 32, 512)  2048        conv2d_447[0][0]
# __________________________________________________________________________________________________
# conv2d_433 (Conv2D)             (None, 32, 32, 512)  2359808     batch_normalization_330[0][0]
# __________________________________________________________________________________________________
# conv2d_448 (Conv2D)             (None, 32, 32, 512)  2359808     batch_normalization_341[0][0]
# __________________________________________________________________________________________________
# batch_normalization_331 (BatchN (None, 32, 32, 512)  2048        conv2d_433[0][0]
# __________________________________________________________________________________________________
# batch_normalization_342 (BatchN (None, 32, 32, 512)  2048        conv2d_448[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_172 (MaxPooling2D (None, 16, 16, 512)  0           batch_normalization_331[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_178 (MaxPooling2D (None, 16, 16, 512)  0           batch_normalization_342[0][0]
# __________________________________________________________________________________________________
# conv2d_434 (Conv2D)             (None, 16, 16, 512)  2359808     max_pooling2d_172[0][0]
# __________________________________________________________________________________________________
# conv2d_449 (Conv2D)             (None, 16, 16, 512)  2359808     max_pooling2d_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_332 (BatchN (None, 16, 16, 512)  2048        conv2d_434[0][0]
# __________________________________________________________________________________________________
# batch_normalization_343 (BatchN (None, 16, 16, 512)  2048        conv2d_449[0][0]
# __________________________________________________________________________________________________
# conv2d_435 (Conv2D)             (None, 16, 16, 512)  2359808     batch_normalization_332[0][0]
# __________________________________________________________________________________________________
# conv2d_450 (Conv2D)             (None, 16, 16, 512)  2359808     batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# batch_normalization_333 (BatchN (None, 16, 16, 512)  2048        conv2d_435[0][0]
# __________________________________________________________________________________________________
# batch_normalization_344 (BatchN (None, 16, 16, 512)  2048        conv2d_450[0][0]
# __________________________________________________________________________________________________
# conv2d_436 (Conv2D)             (None, 16, 16, 512)  2359808     batch_normalization_333[0][0]
# __________________________________________________________________________________________________
# conv2d_451 (Conv2D)             (None, 16, 16, 512)  2359808     batch_normalization_344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_334 (BatchN (None, 16, 16, 512)  2048        conv2d_436[0][0]
# __________________________________________________________________________________________________
# batch_normalization_345 (BatchN (None, 16, 16, 512)  2048        conv2d_451[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_173 (MaxPooling2D (None, 8, 8, 512)    0           batch_normalization_334[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_179 (MaxPooling2D (None, 8, 8, 512)    0           batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_34 (Gl (None, 512)          0           max_pooling2d_173[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_35 (Gl (None, 512)          0           max_pooling2d_179[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 512)          0           global_average_pooling2d_34[0][0]
#                                                                  global_average_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 4024)         2064312     add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_346 (BatchN (None, 4024)         16096       dense_28[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 4024)         0           batch_normalization_346[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 4024)         16196600    dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_347 (BatchN (None, 4024)         16096       dense_29[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 4024)         0           batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_32 (Gl (None, 512)          0           max_pooling2d_173[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_33 (Gl (None, 512)          0           max_pooling2d_179[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 4)            16100       dropout_35[0][0]
# __________________________________________________________________________________________________
# global_output (Dense)           (None, 4)            2052        global_average_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# local_output (Dense)            (None, 4)            2052        global_average_pooling2d_33[0][0]
# ==================================================================================================
# Total params: 51,548,252
# Trainable params: 51,514,748
# Non-trainable params: 33,504
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model = build_bchisto_net()

opt = Adam(learning_rate=0.001)

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss={
        'main_output': 'categorical_crossentropy',
        'global_output': 'categorical_crossentropy',
        'local_output': 'categorical_crossentropy'
    },
    loss_weights={
        'main_output': 1.0,
        'global_output': 0.3,
        'local_output': 0.3
    },
    metrics={'main_output': 'accuracy'}
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    mode='max',
    factor=0.5,
    patience=5,
    verbose=1,
    min_delta=0.0001
)

 
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0001,
    patience=30,
    verbose=1,
    mode='max',
    restore_best_weights=True
)


check_path = '/content/drive/MyDrive/BHC net.weights.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    check_path,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)


history= model.fit(
    train_gen,
    validation_data=val_gen,
    steps_per_epoch=len(train_generator),
    validation_steps=len(val_generator),
    epochs=65,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/65
# 731/731 [==============================] - 757s 1s/step - loss: 1.8232 - main_output_loss: 1.3585 - global_output_loss: 0.7754 - local_output_loss: 0.7734 - main_output_accuracy: 0.6090 - val_loss: 1.5221 - val_main_output_loss: 0.8724 - val_global_output_loss: 0.9044 - val_local_output_loss: 1.2612 - val_main_output_accuracy: 0.6199
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 2/65
# 731/731 [==============================] - 739s 1s/step - loss: 1.2366 - main_output_loss: 0.8610 - global_output_loss: 0.6171 - local_output_loss: 0.6349 - main_output_accuracy: 0.6844 - val_loss: 1.5800 - val_main_output_loss: 0.9198 - val_global_output_loss: 1.2832 - val_local_output_loss: 0.9175 - val_main_output_accuracy: 0.6349
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch
65
# 731/731 [==============================] - 735s 1s/step - loss: 0.0789 - main_output_loss: 0.0350 - global_output_loss: 0.0351 - local_output_loss: 0.1112 - main_output_accuracy: 0.9880 - val_loss: 2.2791 - val_main_output_loss: 1.3721 - val_global_output_loss: 1.1903 - val_local_output_loss: 1.8331 - val_main_output_accuracy: 0.7530
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 63/65
# 731/731 [==============================] - 735s 1s/step - loss: 0.1136 - main_output_loss: 0.0576 - global_output_loss: 0.0494 - local_output_loss: 0.1374 - main_output_accuracy: 0.9830 - val_loss: 0.8641 - val_main_output_loss: 0.5615 - val_global_output_loss: 0.5045 - val_local_output_loss: 0.5041 - val_main_output_accuracy: 0.8622
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 64/65
# 731/731 [==============================] - 735s 1s/step - loss: 0.0799 - main_output_loss: 0.0344 - global_output_loss: 0.0373 - local_output_loss: 0.1142 - main_output_accuracy: 0.9890 - val_loss: 0.5062 - val_main_output_loss: 0.3214 - val_global_output_loss: 0.3664 - val_local_output_loss: 0.2498 - val_main_output_accuracy: 0.9214
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 65/65
# 731/731 [==============================] - 744s 1s/step - loss: 0.0778 - main_output_loss: 0.0355 - global_output_loss: 0.0391 - local_output_loss: 0.1020 - main_output_accuracy: 0.9884 - val_loss: 0.6439 - val_main_output_loss: 0.4286 - val_global_output_loss: 0.4300 - val_local_output_loss: 0.2877 - val_main_output_accuracy: 0.9061
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,main_output_loss,global_output_loss,local_output_loss,main_output_accuracy,val_loss,val_main_output_loss,val_global_output_loss,val_local_output_loss,val_main_output_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['main_output_accuracy'])
plt.plot(history.history['val_main_output_accuracy'], '--')
plt.legend(['Train acc', 'Validation acc'])
plt.title('Main Output Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'], '--')
plt.legend(['Train Loss', 'Validation Loss'])
plt.title('Training / Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# vgg16model.load_weights("./cropModel.h5")
import numpy as np

y_true = test_generator.labels

Y_pred = model.predict(test_gen, steps=len(test_generator))
y_pred = np.argmax(Y_pred[0], axis=1)

print("True classes:")
print(y_true)

print("Predicted classes:")
print(y_pred)
# Out:
# True classes:
# [0 0 0 ... 3 3 3]
# Predicted classes:
# [0 0 0 ... 0 0 2]

# %%
print('Accuracy {}'.format(accuracy_score(y_true=test_generator.labels, y_pred=y_pred)))
print('F1 {}'.format(f1_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('precision {}'.format(precision_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('recall {}'.format(recall_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))

print('jaccard {}'.format(jaccard_score(y_true=test_generator.labels, y_pred=y_pred,average = "macro")))
print('classification_report\n {}'.format(classification_report(y_true=test_generator.labels, y_pred=y_pred)))
print('\n\n')
cm = confusion_matrix(y_true=test_generator.labels, y_pred=y_pred)
print(cm)
# Out:
# Accuracy 0.8079887876664331
# F1 0.8049968326858687
# precision 0.8101674054001264
# recall 0.8073550587343691
# jaccard 0.6797780484815827
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       754
#            1       0.80      0.62      0.70       700
#            2       0.76      0.86      0.81       700
#            3       0.90      0.91      0.90       700
#
#     accuracy                           0.81      2854
#    macro avg       0.81      0.81      0.80      2854
# weighted avg       0.81      0.81      0.81      2854
#
#
#
#
# [[634  94  24   2]
#  [101 436 162   1]
#  [ 20  13 602  65]
#  [ 62   3   1 634]]
