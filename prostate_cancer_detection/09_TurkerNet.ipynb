# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import *
import cv2
import numpy as np
import random
import os 
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\Valid",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\Akshaya\Resampled prostate images with reduced images - Copy\test",
    target_size=(224, 224),
    batch_size=16,
    shuffle=False  # don't shuffle for tseting
)

print("Train classes:", train_generator.class_indices)
print("Validation classes:", val_generator.class_indices)
print("Test classes:", test_generator.class_indices)
# Out:
# Found 11684 images belonging to 4 classes.
# Found 2939 images belonging to 4 classes.
# Found 2854 images belonging to 4 classes.
# Train classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Validation classes: {'0': 0, '1': 1, '2': 2, '3': 3}
# Test classes: {'0': 0, '1': 1, '2': 2, '3': 3}

# %%
def input_block(x):
    x = Conv2D(32, 3, strides=2, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(16, 3, strides=2, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(64, 1, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x
def residual_block(x, C):
    shortcut = x

    x = Conv2D(C, 1, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(C//4, 3, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(C, 1, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)

    x = Add()([x, shortcut])
    x = Activation("relu")(x)
    return x
def se_block(x, C):
    se = GlobalAveragePooling2D()(x)
    se = Reshape((1,1,C))(se)

    se = Conv2D(C//4, 1, activation="relu")(se)
    se = Conv2D(C, 1, activation="sigmoid")(se)

    return Multiply()([x, se])
def decomposition_block(x, C):
    x = MaxPooling2D(3, strides=2, padding="same")(x)
    x = Conv2D(2*C, 1, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x
def TurkerNet(num_classes):
    inputs = Input((224,224,3))

    x = input_block(inputs)   # 56x56x64

    x = residual_block(x, 64)
    x = se_block(x, 64)
    x = decomposition_block(x, 64)   # → 28x28x128

    x = residual_block(x, 128)
    x = se_block(x, 128)
    x = decomposition_block(x, 128)  # → 14x14x256

    x = residual_block(x, 256)
    x = se_block(x, 256)
    x = decomposition_block(x, 256)  # → 7x7x512

    x = residual_block(x, 512)
    x = se_block(x, 512)

    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation="softmax")(x)

    return Model(inputs, x)
model = TurkerNet(num_classes=4)

model.compile(
    optimizer = Adam(1e-4),
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 16)   4608        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   1024        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   4096        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 16)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 64)   1024        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           batch_normalization_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           activation_5[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 64)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 16)     1040        reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 64)     1088        conv2d_6[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 56, 56, 64)   0           activation_5[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 64)   0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  8192        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  16384       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 32)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 128)  4096        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 128)  0           batch_normalization_9[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           activation_9[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 32)     4128        reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 128)    4224        conv2d_12[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 28, 28, 128)  0           activation_9[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 128)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 256)  32768       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 256)  65536       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 64)   147456      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 256)  16384       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 256)  0           batch_normalization_13[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 64)     16448       reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 256)    16640       conv2d_18[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 14, 14, 256)  0           activation_13[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 256)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 7, 7, 512)    131072      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 7, 7, 512)    262144      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 128)    589824      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 512)    65536       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 512)    0           batch_normalization_17[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 512)    0           add_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 512)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 1, 1, 128)    65664       reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 512)    66048       conv2d_24[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 7, 7, 512)    0           activation_17[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            2052        global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 1,587,092
# Trainable params: 1,580,756
# Non-trainable params: 6,336
# __________________________________________________________________________________________________

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    mode='max',
    factor=0.5,
    patience=8,
    verbose=1,
    cooldown=1,
    min_delta=0.0001
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0001,
    patience=30,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

check_path = "TurkerNet_prostate_best.h5"

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    check_path,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)
history = model.fit(
    train_generator,
    validation_data=val_generator,
    steps_per_epoch=len(train_generator),
    validation_steps=len(val_generator),
    epochs=65,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/65
# 731/731 [==============================] - 171s 222ms/step - loss: 0.7215 - accuracy: 0.6796 - val_loss: 0.8848 - val_accuracy: 0.6427
#
# Epoch 00001: val_accuracy improved from -inf to 0.64274, saving model to TurkerNet_prostate_best.h5
# Epoch 2/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.5722 - accuracy: 0.7474 - val_loss: 0.6728 - val_accuracy: 0.7013
#
# Epoch 00002: val_accuracy improved from 0.64274 to 0.70126, saving model to TurkerNet_prostate_best.h5
# Epoch 3/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.5022 - accuracy: 0.7743 - val_loss: 0.4544 - val_accuracy: 0.8013
#
# Epoch 00003: val_accuracy improved from 0.70126 to 0.80129, saving model to TurkerNet_prostate_best.h5
# Epoch 4/65
# 731/731 [==============================] - 22s 31ms/step - loss: 0.4616 - accuracy: 0.7975 - val_loss: 0.6561 - val_accuracy: 0.7118
#
# Epoch 00004: val_accuracy did not improve from 0.80129
# Epoch 5/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.4330 - accuracy: 0.8132 - val_loss: 0.5710 - val_accuracy: 0.7601
#
# Epoch 00005: val_accuracy did not improve from 0.80129
# Epoch 6/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.4051 - accuracy: 0.8240 - val_loss: 0.5256 - val_accuracy: 0.7788
#
# Epoch 00006: val_accuracy did not improve from 0.80129
# Epoch 7/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.3854 - accuracy: 0.8335 - val_loss: 0.3523 - val_accuracy: 0.8544
#
# Epoch 00007: val_accuracy improved from 0.80129 to 0.85437, saving model to TurkerNet_prostate_best.h5
# Epoch 8/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.3714 - accuracy: 0.8431 - val_loss: 0.4291 - val_accuracy: 0.8084
#
# Epoch 00008: val_accuracy did not improve from 0.85437
# Epoch 9/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.3588 - accuracy: 0.8447 - val_loss: 0.5304 - val_accuracy: 0.7877
#
# Epoch 00009: val_accuracy did not improve from 0.85437
# Epoch 10/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.3408 - accuracy: 0.8568 - val_loss: 0.4781 - val_accuracy: 0.7969
#
# Epoch 00010: val_accuracy did not improve from 0.85437
# Epoch 11/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.3281 - accuracy: 0.8606 - val_loss: 0.3659 - val_accuracy: 0.8506
#
# Epoch 00011: val_accuracy did not improve from 0.85437
# Epoch 12/65
# 731/731 [==============================] - 24s 33ms/step - loss: 0.3155 - accuracy: 0.8690 - val_loss: 0.3938 - val_accuracy: 0.8285
#
# Epoch 00012: val_accuracy did not improve from 0.85437
# Epoch 13/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.3066 - accuracy: 0.8714 - val_loss: 0.4719 - val_accuracy: 0.8163
#
# Epoch 00013: val_accuracy did not improve from 0.85437
# Epoch 14/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.2970 - accuracy: 0.8762 - val_loss: 0.3533 - val_accuracy: 0.8534
#
# Epoch 00014: val_accuracy did not improve from 0.85437
# Epoch 15/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.2860 - accuracy: 0.8789 - val_loss: 0.4218 - val_accuracy: 0.8319
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00015: val_accuracy did not improve from 0.85437
# Epoch 16/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.2624 - accuracy: 0.8909 - val_loss: 0.2535 - val_accuracy: 0.8945
#
# Epoch 00016: val_accuracy improved from 0.85437 to 0.89452, saving model to TurkerNet_prostate_best.h5
# Epoch 17/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.2414 - accuracy: 0.9002 - val_loss: 0.3413 - val_accuracy: 0.8612
#
# Epoch 00017: val_accuracy did not improve from 0.89452
# Epoch 18/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.2348 - accuracy: 0.9012 - val_loss: 0.4014 - val_accuracy: 0.8411
#
# Epoch 00018: val_accuracy did not improve from 0.89452
# Epoch 19/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.2325 - accuracy: 0.9023 - val_loss: 0.3011 - val_accuracy: 0.8748
#
# Epoch 00019: val_accuracy did not improve from 0.89452
# Epoch 20/65
# 731/731 [==============================] - 22s 31ms/step - loss: 0.2213 - accuracy: 0.9065 - val_loss: 0.5921 - val_accuracy: 0.7846
#
# Epoch 00020: val_accuracy did not improve from 0.89452
# Epoch 21/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.2170 - accuracy: 0.9101 - val_loss: 0.3149 - val_accuracy: 0.8693
#
# Epoch 00021: val_accuracy did not improve from 0.89452
# Epoch 22/65
# 731/731 [==============================] - 22s 31ms/step - loss: 0.2159 - accuracy: 0.9100 - val_loss: 0.3592 - val_accuracy: 0.8499
#
# Epoch 00022: val_accuracy did not improve from 0.89452
# Epoch 23/65
# 731/731 [==============================] - 22s 30ms/step - loss: 0.2058 - accuracy: 0.9175 - val_loss: 0.3845 - val_accuracy: 0.8602
#
# Epoch 00023: val_accuracy did not improve from 0.89452
# Epoch 24/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1984 - accuracy: 0.9192 - val_loss: 0.3354 - val_accuracy: 0.8744
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00024: val_accuracy did not improve from 0.89452
# Epoch 25/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1815 - accuracy: 0.9273 - val_loss: 0.2480 - val_accuracy: 0.9017
#
# Epoch 00025: val_accuracy improved from 0.89452 to 0.90167, saving model to TurkerNet_prostate_best.h5
# Epoch 26/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1713 - accuracy: 0.9322 - val_loss: 0.2566 - val_accuracy: 0.8976
#
# Epoch 00026: val_accuracy did not improve from 0.90167
# Epoch 27/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1697 - accuracy: 0.9317 - val_loss: 0.2537 - val_accuracy: 0.8989
#
# Epoch 00027: val_accuracy did not improve from 0.90167
# Epoch 28/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1634 - accuracy: 0.9356 - val_loss: 0.2609 - val_accuracy: 0.8979
#
# Epoch 00028: val_accuracy did not improve from 0.90167
# Epoch 29/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1631 - accuracy: 0.9356 - val_loss: 0.2653 - val_accuracy: 0.8915
#
# Epoch 00029: val_accuracy did not improve from 0.90167
# Epoch 30/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1585 - accuracy: 0.9385 - val_loss: 0.2683 - val_accuracy: 0.8986
#
# Epoch 00030: val_accuracy did not improve from 0.90167
# Epoch 31/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1579 - accuracy: 0.9377 - val_loss: 0.2705 - val_accuracy: 0.8935
#
# Epoch 00031: val_accuracy did not improve from 0.90167
# Epoch 32/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1527 - accuracy: 0.9374 - val_loss: 0.2840 - val_accuracy: 0.8853
#
# Epoch 00032: val_accuracy did not improve from 0.90167
# Epoch 33/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1487 - accuracy: 0.9391 - val_loss: 0.2794 - val_accuracy: 0.8945
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00033: val_accuracy did not improve from 0.90167
# Epoch 34/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1391 - accuracy: 0.9456 - val_loss: 0.2418 - val_accuracy: 0.9027
#
# Epoch 00034: val_accuracy improved from 0.90167 to 0.90269, saving model to TurkerNet_prostate_best.h5
# Epoch 35/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1308 - accuracy: 0.9502 - val_loss: 0.2532 - val_accuracy: 0.8996
#
# Epoch 00035: val_accuracy did not improve from 0.90269
# Epoch 36/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1276 - accuracy: 0.9502 - val_loss: 0.2490 - val_accuracy: 0.9034
#
# Epoch 00036: val_accuracy improved from 0.90269 to 0.90337, saving model to TurkerNet_prostate_best.h5
# Epoch 37/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1309 - accuracy: 0.9495 - val_loss: 0.2485 - val_accuracy: 0.9027
#
# Epoch 00037: val_accuracy did not improve from 0.90337
# Epoch 38/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1234 - accuracy: 0.9521 - val_loss: 0.2562 - val_accuracy: 0.9013
#
# Epoch 00038: val_accuracy did not improve from 0.90337
# Epoch 39/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1236 - accuracy: 0.9534 - val_loss: 0.2541 - val_accuracy: 0.9051
#
# Epoch 00039: val_accuracy improved from 0.90337 to 0.90507, saving model to TurkerNet_prostate_best.h5
# Epoch 40/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1228 - accuracy: 0.9537 - val_loss: 0.2628 - val_accuracy: 0.8979
#
# Epoch 00040: val_accuracy did not improve from 0.90507
# Epoch 41/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1236 - accuracy: 0.9526 - val_loss: 0.2609 - val_accuracy: 0.9017
#
# Epoch 00041: val_accuracy did not improve from 0.90507
# Epoch 42/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1151 - accuracy: 0.9558 - val_loss: 0.2585 - val_accuracy: 0.8979
#
# Epoch 00042: val_accuracy did not improve from 0.90507
# Epoch 43/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1166 - accuracy: 0.9540 - val_loss: 0.2573 - val_accuracy: 0.9030
#
# Epoch 00043: val_accuracy did not improve from 0.90507
# Epoch 44/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1168 - accuracy: 0.9563 - val_loss: 0.3000 - val_accuracy: 0.8887
#
# Epoch 00044: val_accuracy did not improve from 0.90507
# Epoch 45/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1113 - accuracy: 0.9578 - val_loss: 0.2767 - val_accuracy: 0.8952
#
# Epoch 00045: val_accuracy did not improve from 0.90507
# Epoch 46/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.1076 - accuracy: 0.9601 - val_loss: 0.2855 - val_accuracy: 0.8925
#
# Epoch 00046: val_accuracy did not improve from 0.90507
# Epoch 47/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.1068 - accuracy: 0.9599 - val_loss: 0.2719 - val_accuracy: 0.9006
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 00047: val_accuracy did not improve from 0.90507
# Epoch 48/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.0994 - accuracy: 0.9610 - val_loss: 0.2557 - val_accuracy: 0.9047
#
# Epoch 00048: val_accuracy did not improve from 0.90507
# Epoch 49/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0981 - accuracy: 0.9637 - val_loss: 0.2679 - val_accuracy: 0.8989
#
# Epoch 00049: val_accuracy did not improve from 0.90507
# Epoch 50/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.1001 - accuracy: 0.9614 - val_loss: 0.2721 - val_accuracy: 0.8972
#
# Epoch 00050: val_accuracy did not improve from 0.90507
# Epoch 51/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.2570 - val_accuracy: 0.9047
#
# Epoch 00051: val_accuracy did not improve from 0.90507
# Epoch 52/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0975 - accuracy: 0.9617 - val_loss: 0.2752 - val_accuracy: 0.8996
#
# Epoch 00052: val_accuracy did not improve from 0.90507
# Epoch 53/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0988 - accuracy: 0.9619 - val_loss: 0.2663 - val_accuracy: 0.9054
#
# Epoch 00053: val_accuracy improved from 0.90507 to 0.90541, saving model to TurkerNet_prostate_best.h5
# Epoch 54/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0951 - accuracy: 0.9633 - val_loss: 0.2637 - val_accuracy: 0.9020
#
# Epoch 00054: val_accuracy did not improve from 0.90541
# Epoch 55/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.0932 - accuracy: 0.9653 - val_loss: 0.2668 - val_accuracy: 0.9054
#
# Epoch 00055: val_accuracy did not improve from 0.90541
# Epoch 56/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0951 - accuracy: 0.9667 - val_loss: 0.2645 - val_accuracy: 0.9034
#
# Epoch 00056: val_accuracy did not improve from 0.90541
# Epoch 57/65
# 731/731 [==============================] - 24s 32ms/step - loss: 0.0934 - accuracy: 0.9658 - val_loss: 0.2674 - val_accuracy: 0.9030
#
# Epoch 00057: val_accuracy did not improve from 0.90541
# Epoch 58/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0881 - accuracy: 0.9676 - val_loss: 0.2724 - val_accuracy: 0.8986
#
# Epoch 00058: val_accuracy did not improve from 0.90541
# Epoch 59/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0895 - accuracy: 0.9646 - val_loss: 0.2783 - val_accuracy: 0.8986
#
# Epoch 00059: val_accuracy did not improve from 0.90541
# Epoch 60/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0878 - accuracy: 0.9669 - val_loss: 0.2797 - val_accuracy: 0.8966
#
# Epoch 00060: val_accuracy did not improve from 0.90541
# Epoch 61/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0885 - accuracy: 0.9665 - val_loss: 0.2753 - val_accuracy: 0.9013
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 00061: val_accuracy did not improve from 0.90541
# Epoch 62/65
# 731/731 [==============================] - 23s 31ms/step - loss: 0.0821 - accuracy: 0.9712 - val_loss: 0.2724 - val_accuracy: 0.9034
#
# Epoch 00062: val_accuracy did not improve from 0.90541
# Epoch 63/65
# 731/731 [==============================] - 25s 34ms/step - loss: 0.0851 - accuracy: 0.9693 - val_loss: 0.2731 - val_accuracy: 0.9020
#
# Epoch 00063: val_accuracy did not improve from 0.90541
# Epoch 64/65
# 731/731 [==============================] - 25s 34ms/step - loss: 0.0866 - accuracy: 0.9690 - val_loss: 0.2778 - val_accuracy: 0.9003
#
# Epoch 00064: val_accuracy did not improve from 0.90541
# Epoch 65/65
# 731/731 [==============================] - 23s 32ms/step - loss: 0.0835 - accuracy: 0.9683 - val_loss: 0.2738 - val_accuracy: 0.9013
#
# Epoch 00065: val_accuracy did not improve from 0.90541

# %%
model.load_weights("TurkerNet_prostate_best.h5")
np.save("TurkerNet_history.npy", history.history)
a = np.load("TurkerNet_history.npy", allow_pickle=True).item()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(a['accuracy'], label='train_acc')
plt.plot(a['val_accuracy'], label='val_acc')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("TurkerNet Training Accuracy")
plt.grid(True)
plt.show()

plt.figure()
plt.plot(a['loss'], label='train_loss')
plt.plot(a['val_loss'], label='val_loss')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("TurkerNet Training Loss")
plt.grid(True)
plt.show()

# %%
import numpy as np

test_generator.reset()
Y_pred = model.predict(test_generator, steps=len(test_generator), verbose=1)
pred_class_indices = np.argmax(Y_pred, axis=1)

y_true = test_generator.labels

print("Predicted classes:", pred_class_indices)
# Out:
# 179/179 [==============================] - 20s 110ms/step
# Predicted classes: [0 0 0 ... 3 3 3]

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score

classes = [0,1,2,3]

for cl in classes:
    print("Class:", cl)

    a1 = np.uint8(y_true == cl)
    a2 = np.uint8(pred_class_indices == cl)

    print('Accuracy {}'.format(accuracy_score(a1, a2)))
    print('F1 {}'.format(f1_score(a1, a2)))
    print('Precision {}'.format(precision_score(a1, a2)))
    print('Recall {}'.format(recall_score(a1, a2)))
    print('Jaccard {}'.format(jaccard_score(a1, a2)))
    print("_______________________________")
from sklearn.metrics import confusion_matrix, classification_report

print('Accuracy {}'.format(accuracy_score(y_true, pred_class_indices)))
print('F1 {}'.format(f1_score(y_true, pred_class_indices, average="macro")))
print('Precision {}'.format(precision_score(y_true, pred_class_indices, average="macro")))
print('Recall {}'.format(recall_score(y_true, pred_class_indices, average="macro")))
print('Jaccard {}'.format(jaccard_score(y_true, pred_class_indices, average="macro")))

print('Confusion Matrix:\n', confusion_matrix(y_true, pred_class_indices))
print('Classification Report:\n', classification_report(y_true, pred_class_indices))
# Out:
# Class: 0
# Accuracy 0.9327259985984583
# F1 0.873850197109067
# Precision 0.8658854166666666
# Recall 0.8819628647214854
# Jaccard 0.7759626604434072
# _______________________________
# Class: 1
# Accuracy 0.9145059565522075
# F1 0.8200589970501475
# Precision 0.8475609756097561
# Recall 0.7942857142857143
# Jaccard 0.695
# _______________________________
# Class: 2
# Accuracy 0.9569025928521373
# F1 0.9141660851360782
# Precision 0.8935879945429741
# Recall 0.9357142857142857
# Jaccard 0.8419023136246787
# _______________________________
# Class: 3
# Accuracy 0.9989488437281009
# F1 0.9978525411596278
# Precision 1.0
# Recall 0.9957142857142857
# Jaccard 0.9957142857142857
# _______________________________
# Accuracy 0.901541695865452
# F1 0.9014819551137302
# Precision 0.9017585967048491
# Recall 0.9019192876089428
# Jaccard 0.8271448149455929
# Confusion Matrix:
#  [[665  67  22   0]
#  [ 90 556  54   0]
#  [ 13  32 655   0]
#  [  0   1   2 697]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87       754
#            1       0.85      0.79      0.82       700
#            2       0.89      0.94      0.91       700
#            3       1.00      1.00      1.00       700
#
#     accuracy                           0.90      2854
#    macro avg       0.90      0.90      0.90      2854
# weighted avg       0.90      0.90      0.90      2854
