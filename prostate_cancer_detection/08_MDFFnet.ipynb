# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import *
import cv2
import numpy as np
import random
import os
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\val",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\test",
    target_size=(224, 224),
    batch_size=16,
    shuffle=False  
)

print("Train classes:", train_generator.class_indices)
print("Validation classes:", val_generator.class_indices)
print("Test classes:", test_generator.class_indices)
# Out:
# Found 6660 images belonging to 4 classes.
# Found 1918 images belonging to 4 classes.
# Found 1293 images belonging to 4 classes.
# Train classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}
# Validation classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}
# Test classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}

# %%
from tensorflow.keras.layers import Input, Reshape, Conv1D, BatchNormalization, Activation, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout

def MDFF_1():
    init = Input((224, 224, 3))
    x = Reshape((224 * 224, 3))(init) 

    x = Conv1D(64, kernel_size=3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv1D(128, kernel_size=3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size=2, strides=2)(x) 
    x = Conv1D(256, kernel_size=3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size=2, strides=2)(x)

    x = Conv1D(512, kernel_size=3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(512, kernel_size=3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size=2, strides=2)(x)

    x = GlobalAveragePooling1D()(x) 

    x = Dense(512)(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    
    x = Dense(512)(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    
    output_f1_5 = Dense(512, activation='relu')(x)

    return init, output_f1_5

import tensorflow as tf
from tensorflow.keras.layers import Reshape, Permute

def channel_shuffle(x, groups):

    batch, height, width, channels = x.shape.as_list()
    channels_per_group = channels // groups
    x = Reshape((height, width, groups, channels_per_group))(x)

    x = Permute((1, 2, 4, 3))(x)
    x = Reshape((height, width, channels))(x)
    return x

from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, BatchNormalization, Activation, Add, Concatenate

def PMS(input_feature):
    C = input_feature.shape[-1]
    groups = 4  

    x1 = Conv2D(C // 4, (1, 1), padding='same')(input_feature) 
    x1 = BatchNormalization()(x1) 
    x1 = channel_shuffle(x1, groups) 
    x1 = DepthwiseConv2D((3, 3), padding='same')(x1) 
    x1 = BatchNormalization()(x1)
    x1 = Conv2D(C, (1, 1), padding='same')(x1)
    x1_out = Add()([x1, input_feature]) 

    x2 = Conv2D(C // 4, (1, 1), padding='same')(input_feature)
    x2 = BatchNormalization()(x2)
    x2 = channel_shuffle(x2, groups) 
    x2 = DepthwiseConv2D((5, 5), padding='same')(x2) 
    x2 = BatchNormalization()(x2)
    x2 = Conv2D(C, (1, 1), padding='same')(x2)
    x2_out = Add()([x2, input_feature]) 

    merged = Concatenate(axis=-1)([x1_out, x2_out])
    adjusted = Conv2D(C, (3, 3), padding='same')(merged) 
    res = Add()([adjusted, input_feature])
    output = Activation('relu')(res) 
    
    return output

def MSAmodule(init):
    
    x = PMS(init)
    x = PMS(x)
    x = PMS(x)
    x = PMS(x)
    top_path = Activation('sigmoid')(x)
    y = GlobalAveragePooling2D()(init)
    C = init.shape[-1]
    y = Reshape((1, 1, C))(y)
    y = Conv2D(C // 4, (1, 1), activation='relu', padding='same')(y)
    y = Conv2D(C, (1, 1), activation='sigmoid', padding='same')(y)
    bottom_path = Multiply()([init, y])
    combined = Add()([top_path, bottom_path])
    output = Activation('relu')(combined)
    
    return output

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Concatenate, GlobalAveragePooling2D, Flatten, Dense
def MDFF_2():
    init = Input((224, 224, 3))
    
    x1 = Conv2D(32, (3, 3), activation='relu', padding='same')(init)
    p1 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x1)
    msa1 = MSAmodule(p1)
    c1 = Concatenate()([p1, msa1])

    x2 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p2 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x2) 
    msa2 = MSAmodule(p2)
    
    p1_down_to_56 = MaxPooling2D((2, 2))(p1) 
    
    c2 = Concatenate()([p2, msa2, p1_down_to_56]) 

    x3 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p3 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x3)
    msa3 = MSAmodule(p3)
    
    p2_down_to_28 = MaxPooling2D((2, 2))(p2)
    p1_down_to_28 = MaxPooling2D((4, 4))(p1) 
    
    c3 = Concatenate()([p3, msa3, p2_down_to_28, p1_down_to_28])

    x4 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p4 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x4)
    msa4 = MSAmodule(p4)
    
    p3_down_to_14 = MaxPooling2D((2, 2))(p3)
    p2_down_to_14 = MaxPooling2D((4, 4))(p2)
    p1_down_to_14 = MaxPooling2D((8, 8))(p1)
    
    c4 = Concatenate()([p4, msa4, p3_down_to_14, p2_down_to_14, p1_down_to_14])

    gap = GlobalAveragePooling2D()(c4) 
    flat = Flatten()(gap) 
    output_f2_5 = Dense(512, activation='relu')(flat) 

    return init, output_f2_5

from tensorflow.keras.layers import Concatenate, Dense, Activation
from tensorflow.keras.models import Model

def MDFF_Net_Final(output_f1_5, output_f2_5, num_classes=4):

    fused_features = Concatenate(axis=-1)([output_f1_5, output_f2_5])
    x = Dense(512, activation='relu')(fused_features)
    predictions = Dense(num_classes, activation='softmax')(x)

    return predictions

input_1d, feat_1d = MDFF_1() 
input_2d, feat_2d = MDFF_2() 
preds = MDFF_Net_Final(feat_1d, feat_2d, num_classes=4)

model = Model(inputs=[input_1d, input_2d], outputs=preds)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 8)  264         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 8)  264         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 8)  32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 112, 112, 8)  32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 112, 112, 4,  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 112, 112, 4,  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 112, 112, 2,  0           reshape_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 112, 112, 2,  0           reshape_3[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 112, 112, 8)  0           permute[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 112, 112, 8)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 112, 112, 8)  80          reshape_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 112, 112, 8)  208         reshape_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 8)  32          depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 112, 112, 8)  32          depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 32) 288         batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 32) 288         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 112, 112, 32) 0           conv2d_2[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 112, 112, 32) 0           conv2d_4[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 112, 112, 64) 0           add[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 32) 18464       concatenate[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 32) 0           conv2d_5[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 112, 112, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 8)  264         activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 8)  264         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 112, 112, 8)  32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 112, 112, 8)  32          conv2d_8[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 112, 112, 4,  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 112, 112, 4,  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 112, 112, 2,  0           reshape_5[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 112, 112, 2,  0           reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 112, 112, 8)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 112, 112, 8)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 112, 112, 8)  80          reshape_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 112, 112, 8)  208         reshape_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 112, 112, 32) 288         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 112, 112, 32) 288         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 112, 112, 32) 0           conv2d_7[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 112, 112, 32) 0           conv2d_9[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112, 112, 64) 0           add_3[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 32) 18464       concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 112, 112, 32) 0           conv2d_10[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 112, 112, 32) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 112, 112, 8)  264         activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 112, 112, 8)  264         activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 112, 112, 8)  32          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 112, 112, 8)  32          conv2d_13[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 112, 112, 4,  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 112, 112, 4,  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 112, 112, 2,  0           reshape_9[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 112, 112, 2,  0           reshape_11[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 112, 112, 8)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 112, 112, 8)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 112, 112, 8)  80          reshape_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 112, 112, 8)  208         reshape_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 32) 288         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 32) 288         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 112, 112, 32) 0           conv2d_12[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 112, 112, 32) 0           conv2d_14[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 64) 0           add_6[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 112, 112, 32) 0           conv2d_15[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 112, 112, 32) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 8)  264         activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 8)  264         activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 112, 112, 8)  32          conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 8)  32          conv2d_18[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 112, 112, 4,  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 112, 112, 4,  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# permute_6 (Permute)             (None, 112, 112, 2,  0           reshape_13[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, 112, 112, 2,  0           reshape_15[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 112, 112, 8)  0           permute_6[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 112, 112, 8)  0           permute_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 112, 112, 8)  80          reshape_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 112, 112, 8)  208         reshape_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 8)  32          depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 112, 112, 32) 288         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 32) 288         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 112, 112, 32) 0           conv2d_17[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 112, 112, 32) 0           conv2d_19[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 64) 0           add_9[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 1, 1, 32)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 112, 112, 32) 0           conv2d_20[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 1, 8)      264         reshape_17[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 112, 112, 32) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 1, 32)     288         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 112, 112, 32) 0           activation_10[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 112, 112, 32) 0           max_pooling2d[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 112, 112, 32) 0           activation_11[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 112, 112, 32) 0           add_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 64) 0           max_pooling2d[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 112, 112, 64) 36928       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 16)   1040        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 16)   1040        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 56, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 56, 16)   64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# permute_8 (Permute)             (None, 56, 56, 4, 4) 0           reshape_18[0][0]
# __________________________________________________________________________________________________
# permute_9 (Permute)             (None, 56, 56, 4, 4) 0           reshape_20[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 56, 56, 16)   0           permute_8[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 56, 56, 16)   0           permute_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 56, 56, 16)   160         reshape_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 56, 56, 16)   416         reshape_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 56, 56, 64)   0           conv2d_25[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 56, 56, 64)   0           conv2d_27[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 128)  0           add_13[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 56, 56, 64)   0           conv2d_28[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 16)   1040        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 16)   1040        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 56, 56, 16)   64          conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 56, 56, 16)   64          conv2d_31[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# permute_10 (Permute)            (None, 56, 56, 4, 4) 0           reshape_22[0][0]
# __________________________________________________________________________________________________
# permute_11 (Permute)            (None, 56, 56, 4, 4) 0           reshape_24[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 56, 56, 16)   0           permute_10[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 56, 56, 16)   0           permute_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 56, 56, 16)   160         reshape_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 56, 56, 16)   416         reshape_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 56, 56, 64)   0           conv2d_30[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 56, 56, 64)   0           conv2d_32[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 56, 56, 128)  0           add_16[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 64)   73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 56, 56, 64)   0           conv2d_33[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 56, 56, 16)   1040        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 16)   1040        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 56, 56, 16)   64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 56, 56, 16)   64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# permute_12 (Permute)            (None, 56, 56, 4, 4) 0           reshape_26[0][0]
# __________________________________________________________________________________________________
# permute_13 (Permute)            (None, 56, 56, 4, 4) 0           reshape_28[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 56, 56, 16)   0           permute_12[0][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 56, 56, 16)   0           permute_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 56, 56, 16)   160         reshape_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 56, 56, 16)   416         reshape_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 56, 56, 64)   0           conv2d_35[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 56, 56, 64)   0           conv2d_37[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 56, 56, 128)  0           add_19[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 64)   73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 56, 56, 64)   0           conv2d_38[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 56, 56, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 16)   1040        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 56, 56, 16)   1040        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 56, 56, 16)   64          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 56, 56, 16)   64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 56, 56, 4, 4) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# permute_14 (Permute)            (None, 56, 56, 4, 4) 0           reshape_30[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (None, 56, 56, 4, 4) 0           reshape_32[0][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 56, 56, 16)   0           permute_14[0][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 56, 56, 16)   0           permute_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 56, 56, 16)   160         reshape_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 56, 56, 16)   416         reshape_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 56, 56, 16)   64          depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 56, 56, 64)   1088        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 56, 56, 64)   0           conv2d_40[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 56, 56, 64)   0           conv2d_42[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 56, 56, 128)  0           add_22[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 56, 56, 64)   73792       concatenate_8[0][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 56, 56, 64)   0           conv2d_43[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 1, 1, 16)     1040        reshape_34[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 1, 1, 64)     1088        conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 64)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 56, 56, 64)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 56, 56, 64)   0           activation_17[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 56, 56, 160)  0           max_pooling2d_1[0][0]
#                                                                  activation_18[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 56, 56, 128)  184448      concatenate_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 28, 28, 32)   4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 28, 28, 32)   4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 32)   128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 28, 28, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 28, 28, 4, 8) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# reshape_37 (Reshape)            (None, 28, 28, 4, 8) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (None, 28, 28, 8, 4) 0           reshape_35[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (None, 28, 28, 8, 4) 0           reshape_37[0][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 28, 28, 32)   0           permute_16[0][0]
# __________________________________________________________________________________________________
# reshape_38 (Reshape)            (None, 28, 28, 32)   0           permute_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 28, 28, 32)   320         reshape_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 28, 28, 32)   832         reshape_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 32)   128         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 28, 28, 32)   128         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 28, 28, 128)  4224        batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 28, 28, 128)  4224        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 28, 28, 128)  0           conv2d_48[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 28, 28, 128)  0           conv2d_50[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# ...
# conv2d_83 (Conv2D)              (None, 14, 14, 256)  16640       batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50176, 64)    256         conv1d[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 14, 14, 256)  0           conv2d_81[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 14, 14, 256)  0           conv2d_83[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 50176, 64)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 14, 14, 512)  0           add_45[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 50176, 128)   24704       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 14, 14, 256)  1179904     concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50176, 128)   512         conv1d_1[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 14, 14, 256)  0           conv2d_84[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 50176, 128)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           add_47[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 25088, 128)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 14, 14, 64)   16448       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 14, 14, 64)   16448       activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 25088, 256)   98560       max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 14, 14, 64)   256         conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 14, 14, 64)   256         conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25088, 256)   1024        conv1d_2[0][0]
# __________________________________________________________________________________________________
# reshape_64 (Reshape)            (None, 14, 14, 4, 16 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# reshape_66 (Reshape)            (None, 14, 14, 4, 16 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 25088, 256)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# permute_30 (Permute)            (None, 14, 14, 16, 4 0           reshape_64[0][0]
# __________________________________________________________________________________________________
# permute_31 (Permute)            (None, 14, 14, 16, 4 0           reshape_66[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 12544, 256)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# reshape_65 (Reshape)            (None, 14, 14, 64)   0           permute_30[0][0]
# __________________________________________________________________________________________________
# reshape_67 (Reshape)            (None, 14, 14, 64)   0           permute_31[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 12544, 512)   393728      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 14, 14, 64)   640         reshape_65[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 14, 14, 64)   1664        reshape_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12544, 512)   2048        conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 14, 14, 64)   256         depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 14, 14, 64)   256         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12544, 512)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 14, 14, 256)  16640       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 14, 14, 256)  16640       batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 12544, 512)   786944      activation_3[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 14, 14, 256)  0           conv2d_86[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 14, 14, 256)  0           conv2d_88[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 12544, 512)   2048        conv1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 512)  0           add_48[0][0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12544, 512)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 14, 14, 256)  1179904     concatenate_18[0][0]
# __________________________________________________________________________________________________
# reshape_68 (Reshape)            (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6272, 512)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 14, 14, 256)  0           conv2d_89[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 1, 1, 64)     16448       reshape_68[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 512)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 256)  0           add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 1, 1, 256)    16640       conv2d_90[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           activation_28[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 14, 14, 256)  0           max_pooling2d_6[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 14, 14, 256)  0           activation_29[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           add_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 736)  0           max_pooling2d_6[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 736)          0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           activation_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 736)          0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          377344      flatten[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 1024)         0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          524800      concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            2052        dense_4[0][0]
# ==================================================================================================
# Total params: 10,727,004
# Trainable params: 10,720,220
# Non-trainable params: 6,784
# __________________________________________________________________________________________________

# %%
def dual_input_generator(generator):
 
    for x, y in generator:
        yield [x, x], y

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='mdff_net_best.keras',
        monitor='val_accuracy',
        save_best_only=True, # 
        verbose=1
    )
]
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = val_generator.samples // val_generator.batch_size
history = model.fit(
    dual_input_generator(train_generator),
    epochs=65, 
    steps_per_epoch=steps_per_epoch,
    validation_data=dual_input_generator(val_generator),
    validation_steps=validation_steps,
    callbacks=callbacks
)

model.save('mdff_net_prostate_classification.h5') 
print("Model saved successfully as h5 file.")
# Out:
# Epoch 1/65
# 416/416 [==============================] - 475s 1s/step - loss: 0.8534 - accuracy: 0.6224 - val_loss: 1.4442 - val_accuracy: 0.3498
#
# Epoch 00001: val_accuracy improved from -inf to 0.34979, saving model to mdff_net_best.keras
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/65
# 416/416 [==============================] - 461s 1s/step - loss: 0.7249 - accuracy: 0.6722 - val_loss: 1.3642 - val_accuracy: 0.5383
#
# Epoch 00002: val_accuracy improved from 0.34979 to 0.53834, saving model to mdff_net_best.keras
# Epoch 3/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.6391 - accuracy: 0.7155 - val_loss: 1.6589 - val_accuracy: 0.3372
#
# Epoch 00003: val_accuracy did not improve from 0.53834
# Epoch 4/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.5997 - accuracy: 0.7319 - val_loss: 0.8243 - val_accuracy: 0.6329
#
# Epoch 00004: val_accuracy improved from 0.53834 to 0.63288, saving model to mdff_net_best.keras
# Epoch 5/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.5729 - accuracy: 0.7434 - val_loss: 0.5235 - val_accuracy: 0.7705
#
# Epoch 00005: val_accuracy improved from 0.63288 to 0.77048, saving model to mdff_net_best.keras
# Epoch 6/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.5578 - accuracy: 0.7524 - val_loss: 2.1463 - val_accuracy: 0.5851
#
# Epoch 00006: val_accuracy did not improve from 0.77048
# Epoch 7/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.5347 - accuracy: 0.7673 - val_loss: 0.7547 - val_accuracy: 0.6560
#
# Epoch 00007: val_accuracy did not improve from 0.77048
# Epoch 8/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.5344 - accuracy: 0.7651 - val_loss: 0.5382 - val_accuracy: 0.7679
#
# Epoch 00008: val_accuracy did not improve from 0.77048
# Epoch 9/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.5187 - accuracy: 0.7673 - val_loss: 2.3927 - val_accuracy: 0.3241
#
# Epoch 00009: val_accuracy did not improve from 0.77048
# Epoch 10/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.5077 - accuracy: 0.7729 - val_loss: 0.8263 - val_accuracy: 0.6949
#
# Epoch 00010: val_accuracy did not improve from 0.77048
# Epoch 11/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4900 - accuracy: 0.7845 - val_loss: 2.1049 - val_accuracy: 0.5021
#
# Epoch 00011: val_accuracy did not improve from 0.77048
# Epoch 12/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.4865 - accuracy: 0.7878 - val_loss: 0.9105 - val_accuracy: 0.6864
#
# Epoch 00012: val_accuracy did not improve from 0.77048
# Epoch 13/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.4813 - accuracy: 0.7921 - val_loss: 0.7333 - val_accuracy: 0.6970
#
# Epoch 00013: val_accuracy did not improve from 0.77048
# Epoch 14/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4762 - accuracy: 0.7905 - val_loss: 0.5379 - val_accuracy: 0.7558
#
# Epoch 00014: val_accuracy did not improve from 0.77048
# Epoch 15/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.4641 - accuracy: 0.7952 - val_loss: 1.5954 - val_accuracy: 0.4354
#
# Epoch 00015: val_accuracy did not improve from 0.77048
# Epoch 16/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4581 - accuracy: 0.8045 - val_loss: 0.6457 - val_accuracy: 0.7106
#
# Epoch 00016: val_accuracy did not improve from 0.77048
# Epoch 17/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4536 - accuracy: 0.7967 - val_loss: 0.5186 - val_accuracy: 0.7663
#
# Epoch 00017: val_accuracy did not improve from 0.77048
# Epoch 18/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4505 - accuracy: 0.8040 - val_loss: 1.0489 - val_accuracy: 0.5572
#
# Epoch 00018: val_accuracy did not improve from 0.77048
# Epoch 19/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4503 - accuracy: 0.7986 - val_loss: 1.0656 - val_accuracy: 0.5399
#
# Epoch 00019: val_accuracy did not improve from 0.77048
# Epoch 20/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4405 - accuracy: 0.8084 - val_loss: 0.9673 - val_accuracy: 0.6801
#
# Epoch 00020: val_accuracy did not improve from 0.77048
# Epoch 21/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4318 - accuracy: 0.8140 - val_loss: 0.7671 - val_accuracy: 0.6759
#
# Epoch 00021: val_accuracy did not improve from 0.77048
# Epoch 22/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4317 - accuracy: 0.8141 - val_loss: 0.4876 - val_accuracy: 0.7857
#
# Epoch 00022: val_accuracy improved from 0.77048 to 0.78571, saving model to mdff_net_best.keras
# Epoch 23/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.4171 - accuracy: 0.8203 - val_loss: 0.6648 - val_accuracy: 0.7279
#
# Epoch 00023: val_accuracy did not improve from 0.78571
# Epoch 24/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4112 - accuracy: 0.8238 - val_loss: 1.2942 - val_accuracy: 0.6507
#
# Epoch 00024: val_accuracy did not improve from 0.78571
# Epoch 25/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4208 - accuracy: 0.8174 - val_loss: 1.5622 - val_accuracy: 0.5809
#
# Epoch 00025: val_accuracy did not improve from 0.78571
# Epoch 26/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4091 - accuracy: 0.8238 - val_loss: 2.3340 - val_accuracy: 0.4018
#
# Epoch 00026: val_accuracy did not improve from 0.78571
# Epoch 27/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4003 - accuracy: 0.8265 - val_loss: 0.6074 - val_accuracy: 0.7626
#
# Epoch 00027: val_accuracy did not improve from 0.78571
# Epoch 28/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.4106 - accuracy: 0.8244 - val_loss: 0.5010 - val_accuracy: 0.7925
#
# Epoch 00028: val_accuracy improved from 0.78571 to 0.79254, saving model to mdff_net_best.keras
# Epoch 29/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.3980 - accuracy: 0.8269 - val_loss: 0.9341 - val_accuracy: 0.6161
#
# Epoch 00029: val_accuracy did not improve from 0.79254
# Epoch 30/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.3974 - accuracy: 0.8221 - val_loss: 0.6824 - val_accuracy: 0.7290
#
# Epoch 00030: val_accuracy did not improve from 0.79254
# Epoch 31/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3829 - accuracy: 0.8337 - val_loss: 0.4987 - val_accuracy: 0.7794
#
# Epoch 00031: val_accuracy did not improve from 0.79254
# Epoch 32/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3739 - accuracy: 0.8405 - val_loss: 0.6331 - val_accuracy: 0.6996
#
# Epoch 00032: val_accuracy did not improve from 0.79254
# Epoch 33/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3841 - accuracy: 0.8341 - val_loss: 1.1644 - val_accuracy: 0.5509
#
# Epoch 00033: val_accuracy did not improve from 0.79254
# Epoch 34/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3843 - accuracy: 0.8390 - val_loss: 0.6368 - val_accuracy: 0.7164
#
# Epoch 00034: val_accuracy did not improve from 0.79254
# Epoch 35/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3828 - accuracy: 0.8329 - val_loss: 0.6730 - val_accuracy: 0.7222
#
# Epoch 00035: val_accuracy did not improve from 0.79254
# Epoch 36/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3731 - accuracy: 0.8414 - val_loss: 0.6264 - val_accuracy: 0.7458
#
# Epoch 00036: val_accuracy did not improve from 0.79254
# Epoch 37/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3695 - accuracy: 0.8424 - val_loss: 1.4480 - val_accuracy: 0.4874
#
# Epoch 00037: val_accuracy did not improve from 0.79254
# Epoch 38/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3778 - accuracy: 0.8402 - val_loss: 0.9287 - val_accuracy: 0.6276
#
# Epoch 00038: val_accuracy did not improve from 0.79254
# Epoch 39/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3600 - accuracy: 0.8456 - val_loss: 1.0128 - val_accuracy: 0.7043
#
# Epoch 00039: val_accuracy did not improve from 0.79254
# Epoch 40/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3550 - accuracy: 0.8478 - val_loss: 1.3063 - val_accuracy: 0.6071
#
# Epoch 00040: val_accuracy did not improve from 0.79254
# Epoch 41/65
# 416/416 [==============================] - 461s 1s/step - loss: 0.3612 - accuracy: 0.8442 - val_loss: 0.6473 - val_accuracy: 0.7521
#
# Epoch 00041: val_accuracy did not improve from 0.79254
# Epoch 42/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3529 - accuracy: 0.8469 - val_loss: 0.5406 - val_accuracy: 0.7731
#
# Epoch 00042: val_accuracy did not improve from 0.79254
# Epoch 43/65
# 416/416 [==============================] - 459s 1s/step - loss: 0.3537 - accuracy: 0.8480 - val_loss: 1.5713 - val_accuracy: 0.5152
#
# Epoch 00043: val_accuracy did not improve from 0.79254
# Epoch 44/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3471 - accuracy: 0.8520 - val_loss: 0.5527 - val_accuracy: 0.7658
#
# Epoch 00044: val_accuracy did not improve from 0.79254
# Epoch 45/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3478 - accuracy: 0.8483 - val_loss: 0.5323 - val_accuracy: 0.7668
#
# Epoch 00045: val_accuracy did not improve from 0.79254
# Epoch 46/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3515 - accuracy: 0.8520 - val_loss: 0.4528 - val_accuracy: 0.8188
#
# Epoch 00046: val_accuracy improved from 0.79254 to 0.81880, saving model to mdff_net_best.keras
# Epoch 47/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3489 - accuracy: 0.8523 - val_loss: 0.6318 - val_accuracy: 0.7222
#
# Epoch 00047: val_accuracy did not improve from 0.81880
# Epoch 48/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3408 - accuracy: 0.8501 - val_loss: 0.3945 - val_accuracy: 0.8304
#
# Epoch 00048: val_accuracy improved from 0.81880 to 0.83036, saving model to mdff_net_best.keras
# Epoch 49/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3351 - accuracy: 0.8561 - val_loss: 0.7745 - val_accuracy: 0.7195
#
# Epoch 00049: val_accuracy did not improve from 0.83036
# Epoch 50/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3358 - accuracy: 0.8525 - val_loss: 0.5776 - val_accuracy: 0.7826
#
# Epoch 00050: val_accuracy did not improve from 0.83036
# Epoch 51/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3325 - accuracy: 0.8576 - val_loss: 0.9357 - val_accuracy: 0.6833
#
# Epoch 00051: val_accuracy did not improve from 0.83036
# Epoch 52/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3334 - accuracy: 0.8581 - val_loss: 1.2922 - val_accuracy: 0.5100
#
# Epoch 00052: val_accuracy did not improve from 0.83036
# Epoch 53/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3313 - accuracy: 0.8593 - val_loss: 0.7659 - val_accuracy: 0.7269
#
# Epoch 00053: val_accuracy did not improve from 0.83036
# Epoch 54/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3084 - accuracy: 0.8691 - val_loss: 0.4803 - val_accuracy: 0.7962
#
# Epoch 00054: val_accuracy did not improve from 0.83036
# Epoch 55/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3308 - accuracy: 0.8584 - val_loss: 0.4962 - val_accuracy: 0.8188
#
# Epoch 00055: val_accuracy did not improve from 0.83036
# Epoch 56/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3177 - accuracy: 0.8656 - val_loss: 0.6935 - val_accuracy: 0.7489
#
# Epoch 00056: val_accuracy did not improve from 0.83036
# Epoch 57/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3082 - accuracy: 0.8719 - val_loss: 0.6382 - val_accuracy: 0.7841
#
# Epoch 00057: val_accuracy did not improve from 0.83036
# Epoch 58/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3170 - accuracy: 0.8642 - val_loss: 1.6191 - val_accuracy: 0.5000
#
# Epoch 00058: val_accuracy did not improve from 0.83036
# Epoch 59/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3093 - accuracy: 0.8707 - val_loss: 0.8621 - val_accuracy: 0.7164
#
# Epoch 00059: val_accuracy did not improve from 0.83036
# Epoch 60/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3082 - accuracy: 0.8686 - val_loss: 0.5000 - val_accuracy: 0.8025
#
# Epoch 00060: val_accuracy did not improve from 0.83036
# Epoch 61/65
# 416/416 [==============================] - 458s 1s/step - loss: 0.3088 - accuracy: 0.8707 - val_loss: 0.8642 - val_accuracy: 0.7069
#
# Epoch 00061: val_accuracy did not improve from 0.83036
# Epoch 62/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.3047 - accuracy: 0.8731 - val_loss: 1.0814 - val_accuracy: 0.6759
#
# Epoch 00062: val_accuracy did not improve from 0.83036
# Epoch 63/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.2991 - accuracy: 0.8737 - val_loss: 0.4949 - val_accuracy: 0.8072
#
# Epoch 00063: val_accuracy did not improve from 0.83036
# Epoch 64/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.2940 - accuracy: 0.8776 - val_loss: 0.7028 - val_accuracy: 0.7374
#
# Epoch 00064: val_accuracy did not improve from 0.83036
# Epoch 65/65
# 416/416 [==============================] - 457s 1s/step - loss: 0.2986 - accuracy: 0.8770 - val_loss: 0.7870 - val_accuracy: 0.7710
#
# Epoch 00065: val_accuracy did not improve from 0.83036
# Model saved successfully as h5 file.

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'], '--')
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.title('Training / Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'], '--')
plt.legend(['Train Loss', 'Validation Loss'])
plt.title('Training / Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
def dual_input_generator(generator):
    for x, y in generator:
        yield {
            "input_9": x,
            "input_10": x
        }, y
test_steps = test_generator.samples // test_generator.batch_size

Y_pred = model.predict(
    dual_input_generator(test_generator),
    steps=test_steps
)

y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.labels[:len(y_pred)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       3         yield {
#       4             "input_9": x,
#       5             "input_10": x
#       6         }, y
#       7 test_steps = test_generator.samples // test_generator.batch_size
# ----> 9 Y_pred = model.predict(
#      10     dual_input_generator(test_generator),
#      11     steps=test_steps
#      12 )
#      14 y_pred = np.argmax(Y_pred, axis=1)
#      15 y_true = test_generator.labels[:len(y_pred)]
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:1727, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1725 for step in data_handler.steps():
#    1726   callbacks.on_predict_batch_begin(step)
# -> 1727   tmp_batch_outputs = self.predict_function(iterator)
#    1728   if data_handler.should_sync:
#    1729     context.async_wait()
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\def_function.py:889, in Function.__call__(self, *args, **kwds)
#     886 compiler = "xla" if self._jit_compile else "nonXla"
#     888 with OptionalXlaContext(self._jit_compile):
# --> 889   result = self._call(*args, **kwds)
#     891 new_tracing_count = self.experimental_get_tracing_count()
#     892 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\def_function.py:933, in Function._call(self, *args, **kwds)
#     930 try:
#     931   # This is the first call of __call__, so we have to initialize.
#     932   initializers = []
# --> 933   self._initialize(args, kwds, add_initializers_to=initializers)
#     934 finally:
#     935   # At this point we know that the initialization is complete (or less
#     936   # interestingly an exception was raised) so we no longer need a lock.
#     937   self._lock.release()
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\def_function.py:763, in Function._initialize(self, args, kwds, add_initializers_to)
#     760 self._lifted_initializer_graph = lifted_initializer_graph
#     761 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762 self._concrete_stateful_fn = (
# --> 763     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764         *args, **kwds))
#     766 def invalid_creator_scope(*unused_args, **unused_kwds):
#     767   """Disables variable creation."""
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\function.py:3050, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048   args, kwargs = None, None
#    3049 with self._lock:
# -> 3050   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051 return graph_function
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\function.py:3444, in Function._maybe_define_function(self, args, kwargs)
#    3440   return self._define_function_with_shape_relaxation(
#    3441       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3443 self._function_cache.missed.add(call_context_key)
# -> 3444 graph_function = self._create_graph_function(args, kwargs)
#    3445 self._function_cache.primary[cache_key] = graph_function
#    3447 return graph_function, filtered_flat_args
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\function.py:3279, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3274 missing_arg_names = [
#    3275     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3276 ]
#    3277 arg_names = base_arg_names + missing_arg_names
#    3278 graph_function = ConcreteFunction(
# -> 3279     func_graph_module.func_graph_from_py_func(
#    3280         self._name,
#    3281         self._python_function,
#    3282         args,
#    3283         kwargs,
#    3284         self.input_signature,
#    3285         autograph=self._autograph,
#    3286         autograph_options=self._autograph_options,
#    3287         arg_names=arg_names,
#    3288         override_flat_arg_shapes=override_flat_arg_shapes,
#    3289         capture_by_value=self._capture_by_value),
#    3290     self._function_attributes,
#    3291     function_spec=self.function_spec,
#    3292     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3293     # scope. This is not the default behavior since it gets used in some
#    3294     # places (like Keras) where the FuncGraph lives longer than the
#    3295     # ConcreteFunction.
#    3296     shared_func_graph=False)
#    3297 return graph_function
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\framework\func_graph.py:999, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     996 else:
#     997   _, original_func = tf_decorator.unwrap(python_func)
# --> 999 func_outputs = python_func(*func_args, **func_kwargs)
#    1001 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1002 # TensorArrays and `None`s.
#    1003 func_outputs = nest.map_structure(convert, func_outputs,
#    1004                                   expand_composites=True)
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\eager\def_function.py:672, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     668 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     669   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     670   # the function a weak reference to itself to avoid a reference cycle.
#     671   with OptionalXlaContext(compile_with_xla):
# --> 672     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673   return out
#
# File ~\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\framework\func_graph.py:986, in func_graph_from_py_func.<locals>.wrapper(*args, **kwargs)
#     984 except Exception as e:  # pylint:disable=broad-except
#     985   if hasattr(e, "ag_error_metadata"):
# --> 986     raise e.ag_error_metadata.to_exception(e)
#     987   else:
#     988     raise
#
# ValueError: in user code:
#
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:1569 predict_function  *
#         return step_function(self, iterator)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:1559 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:1552 run_step  **
#         outputs = model.predict_step(data)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:1525 predict_step
#         return self(x, training=False)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:183 assert_input_compatibility
#         raise ValueError('Missing data for input "%s". '
#
#     ValueError: Missing data for input "input_1". You passed a data dictionary with keys ['input_9', 'input_10']. Expected the following keys: ['input_1', 'input_2']

# %%
n = len(y_pred)
y_true = test_generator.labels[:n]
from sklearn.metrics import *

print("Accuracy:", accuracy_score(y_true, y_pred))
print("F1:", f1_score(y_true, y_pred, average="macro"))
print("Precision:", precision_score(y_true, y_pred, average="macro"))
print("Recall:", recall_score(y_true, y_pred, average="macro"))
print("Jaccard:", jaccard_score(y_true, y_pred, average="macro"))

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

# %%
class_names = list(test_generator.class_indices.keys())
print(class_names)
for i in range(10):  
    print("True:", class_names[y_true[i]], 
          "Pred:", class_names[y_pred[i]])
for i in range(5):
    print("Image", i)
    for j, cls in enumerate(class_names):
        print(f"  {cls}: {Y_pred[i][j]:.4f}")
