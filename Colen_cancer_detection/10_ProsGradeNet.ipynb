# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import *
import cv2
import numpy as np
import random
import os
import pandas as pd
import warnings
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    Concatenate, Activation, Multiply, Reshape,
    GlobalAveragePooling2D, Dense, AveragePooling2D, Lambda, BatchNormalization
)
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\train",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\val",
    target_size=(224, 224),
    batch_size=16,
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    directory=r"D:\SujanD datasets\Cancer cells\test",
    target_size=(224, 224),
    batch_size=16,
    shuffle=False  
)

print("Train classes:", train_generator.class_indices)
print("Validation classes:", val_generator.class_indices)
print("Test classes:", test_generator.class_indices)
# Out:
# Found 6660 images belonging to 4 classes.
# Found 1918 images belonging to 4 classes.
# Found 1293 images belonging to 4 classes.
# Train classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}
# Validation classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}
# Test classes: {'A': 0, 'B': 1, 'C': 2, 'D': 3}

# %%
train_dir =r"D:\Akshaya\Resampled prostate images with reduced images - Copy\train"
test_dir =  r"D:\Akshaya\Resampled prostate images with reduced images - Copy\Valid"
valid_dir = r"D:\Akshaya\Resampled prostate images with reduced images - Copy\test"
from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size= 4
img_height =256
img_width =256
no_of_classes = 4
classes_name=['Class 0','Class 1','Class 2','Class 3']
input_shape = (img_height, img_width, 3)
random_seed =np.random.seed(52)

datagen = ImageDataGenerator( rescale=1. / 255,
                             featurewise_center=True,
                             horizontal_flip = False,
                             vertical_flip = False,
                             #validation_split = 0.1,
                             featurewise_std_normalization=True)

train_generator = datagen.flow_from_directory(train_dir,
                                               target_size=(img_height, img_width),
                                               batch_size=batch_size,
                                               shuffle = True,
                                               class_mode='categorical')

validation_generator = datagen.flow_from_directory(valid_dir,
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size,
                                                   shuffle = True,
                                                   class_mode='categorical')
# Out:
# Found 11684 images belonging to 4 classes.
# Found 2854 images belonging to 4 classes.

# %%
def conv_block(filter,x):
  b0=Conv2D(filter,(3,3),padding='same')(x)
  b1=BatchNormalization()(b0)
  b2=Activation('relu')(b1)
  return b2
def residual_block(filter,x):
  w,h,c = x.shape[1],x.shape[2],x.shape[3]
  r0=AveragePooling2D(pool_size=(w,h))(x)
  r0=Conv2D(filter,(1,1),activation='sigmoid',padding='same')(r0)
  r1=Multiply()([x,r0])
  return r1
def context_guided(x,y):
    x1 = tf.math.reduce_mean(x, axis=3, name=None,keepdims=True)
    x2 = tf.math.reduce_max(x, axis=3, name=None,keepdims=True)
    x12 = Concatenate()([x1,x2])
    x12 = Conv2D(1,1)(x12)
    x12 = Activation('sigmoid')(x12)
    xy12 = Multiply()([y,x12])
    xy = Add()([xy12,x])
    return xy
def scr_block(x,y,filters,gr):
  y1 = y
  _,width,height,channel=list(x.shape)
  get_channel=channel//gr
  x=Reshape([width,height,get_channel,gr])(x)
  x=Permute([1,2,4,3])(x)
   
  _,width,height,channel=list(y.shape)
  get_channel=channel//gr
  y=Reshape([width,height,get_channel,gr])(y)
  y=Permute([1,2,4,3])(y)

  for i in range(gr):
        if i != 0 and i!=(gr-1):
            concat1 = y[:,:,:,0]
            for j in range(1,i):
                concat1 = Concatenate()([concat1,y[:,:,:,j]])
            concat1 = Concatenate()([concat1,(x[:,:,:,i]+y[:,:,:,i])])
            for j in range(i+1,gr):
                concat1 = Concatenate()([concat1,x[:,:,:,j]])
        elif i == (gr-1):
            concat1 = y[:,:,:,0]
            for j in range(1,i):
                concat1 = Concatenate()([concat1,y[:,:,:,j]])
            concat1 = Concatenate()([concat1,(x[:,:,:,i]+y[:,:,:,i])])
        else:
            concat1 = x[:,:,:,0]+y[:,:,:,0]
            for j in range(1,gr):
                concat1 = Concatenate()([concat1,y[:,:,:,j]])  
        res_x = residual_block(channel,concat1)
        if i==0:
            x_out = res_x
        else:
            x_out = Concatenate()([x_out,res_x])
  x_out = Conv2D(channel,1,padding='same',activation='relu')(x_out)
  x_out = context_guided(x_out,y1)
  x_out = Conv2D(channel,1,padding='same')(x_out)
  return x_out

def resnet_block(block_input,filters,gr):
  conv1=conv_block(filters,block_input)
  conv2=scr_block(block_input,conv1,filters,gr)
  sum=Add()([conv2,block_input])
  res_out=Activation('relu')(sum)
  return res_out

def ProsGradNet():
  input = Input(shape=(256,256,3))
  conv1 = conv_block(16,input)
  scr1 = resnet_block(conv1,16,2)
  scr2 = resnet_block(conv1,16,4)
  scr3 = resnet_block(conv1,16,8)
  Add1 = Add()([scr1,scr2,scr3])
  pool1 = AveragePooling2D((2,2),(2,2))(Add1)
  conv2 = conv_block(32,pool1)
  scr4 = resnet_block(conv2,32,2)
  scr5 = resnet_block(conv2,32,4)
  scr6 = resnet_block(conv2,32,8)
  Add2 = Add()([scr4,scr5,scr6])
  pool2 = MaxPooling2D((2,2),(2,2))(Add2)
  conv3 = conv_block(64,pool2)
  scr7 = resnet_block(conv3,64,2)
  scr8 = resnet_block(conv3,64,4)
  scr9 = resnet_block(conv3,64,8)
  Add3 = Add()([scr7,scr8,scr9])
  pool3 = GlobalAveragePooling2D()(Add3)
  output = Dense(4, activation='softmax')(pool3)
  model = Model(inputs = input, outputs = output)
  return model
model = ProsGradNet()
model.compile(optimizer = 'Adam' , loss = 'categorical_crossentropy' , metrics = ["acc"])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 16) 64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 256, 256, 2,  0           activation[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 256, 256, 2,  0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 256, 256, 8,  0           reshape_4[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 256, 256, 8,  0           reshape_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_26 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_27 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_36 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_37 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 256, 256, 2)  0           tf.__operators__.getitem_26[0][0]
#                                                                  tf.__operators__.getitem_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_28 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_35 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 256, 256, 2)  0           tf.__operators__.getitem_36[0][0]
#                                                                  tf.__operators__.getitem_37[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.add_6[0][0]
#                                                                  tf.__operators__.getitem_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_29 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_35[0][0]
#                                                                  tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_38 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_44 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_45 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_46 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_47 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 256, 256, 6)  0           concatenate_20[0][0]
#                                                                  tf.__operators__.getitem_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_30 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 256, 256, 6)  0           concatenate_27[0][0]
#                                                                  tf.__operators__.getitem_38[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_39 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_44[0][0]
#                                                                  tf.__operators__.getitem_45[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 256, 256, 2)  0           tf.__operators__.getitem_46[0][0]
#                                                                  tf.__operators__.getitem_47[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_53 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_54 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 256, 256, 8)  0           concatenate_21[0][0]
#                                                                  tf.__operators__.getitem_30[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_31 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 256, 256, 8)  0           concatenate_28[0][0]
#                                                                  tf.__operators__.getitem_39[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_40 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 256, 256, 6)  0           concatenate_35[0][0]
#                                                                  tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_48 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_53[0][0]
#                                                                  tf.__operators__.getitem_54[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_55 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_56 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_57 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_62 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_63 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 256, 256, 10) 0           concatenate_22[0][0]
#                                                                  tf.__operators__.getitem_31[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_32 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 256, 256, 10) 0           concatenate_29[0][0]
#                                                                  tf.__operators__.getitem_40[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 256, 256, 8)  0           concatenate_36[0][0]
#                                                                  tf.__operators__.getitem_48[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_49 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 256, 256, 6)  0           concatenate_43[0][0]
#                                                                  tf.__operators__.getitem_55[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 256, 256, 2)  0           tf.__operators__.getitem_56[0][0]
#                                                                  tf.__operators__.getitem_57[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_62[0][0]
#                                                                  tf.__operators__.getitem_63[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_64 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_71 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_72 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 256, 256, 4,  0           activation[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 256, 256, 4,  0           activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 256, 256, 12) 0           concatenate_23[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_33 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 256, 256, 12) 0           concatenate_30[0][0]
#                                                                  tf.__operators__.getitem_41[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_42 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 256, 256, 10) 0           concatenate_37[0][0]
#                                                                  tf.__operators__.getitem_49[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_50 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 256, 256, 8)  0           concatenate_44[0][0]
#                                                                  tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_58 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 256, 256, 6)  0           concatenate_51[0][0]
#                                                                  tf.__operators__.getitem_64[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_65 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_66 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_67 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_71[0][0]
#                                                                  tf.__operators__.getitem_72[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_73 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_80 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_81 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 256, 256, 4,  0           reshape_2[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 256, 256, 4,  0           reshape_3[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 14) 0           concatenate_24[0][0]
#                                                                  tf.__operators__.getitem_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_34 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 256, 256, 14) 0           concatenate_31[0][0]
#                                                                  tf.__operators__.getitem_42[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_43 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 256, 256, 12) 0           concatenate_38[0][0]
#                                                                  tf.__operators__.getitem_50[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_51 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 256, 256, 10) 0           concatenate_45[0][0]
#                                                                  tf.__operators__.getitem_58[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_59 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 256, 256, 8)  0           concatenate_52[0][0]
#                                                                  tf.__operators__.getitem_65[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 256, 256, 2)  0           tf.__operators__.getitem_66[0][0]
#                                                                  tf.__operators__.getitem_67[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 256, 256, 6)  0           concatenate_59[0][0]
#                                                                  tf.__operators__.getitem_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_74 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_80[0][0]
#                                                                  tf.__operators__.getitem_81[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_82 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_89 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_90 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_12 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_13 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 256, 256, 16) 0           concatenate_25[0][0]
#                                                                  tf.__operators__.getitem_34[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 256, 256, 16) 0           concatenate_32[0][0]
#                                                                  tf.__operators__.getitem_43[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 256, 256, 14) 0           concatenate_39[0][0]
#                                                                  tf.__operators__.getitem_51[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_52 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 256, 256, 12) 0           concatenate_46[0][0]
#                                                                  tf.__operators__.getitem_59[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_60 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 256, 256, 10) 0           concatenate_53[0][0]
#                                                                  tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_68 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 256, 256, 8)  0           concatenate_60[0][0]
#                                                                  tf.__operators__.getitem_74[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_75 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_76 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_77 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 256, 256, 6)  0           concatenate_67[0][0]
#                                                                  tf.__operators__.getitem_82[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_83 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 256, 256, 4)  0           tf.__operators__.getitem_89[0][0]
#                                                                  tf.__operators__.getitem_90[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_91 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 256, 256, 4)  0           tf.__operators__.getitem_6[0][0]
#                                                                  tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 256, 256, 4)  0           tf.__operators__.getitem_12[0][0]
#                                                                  tf.__operators__.getitem_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 16)     0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 1, 1, 16)     0           concatenate_33[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 256, 256, 16) 0           concatenate_40[0][0]
#                                                                  tf.__operators__.getitem_52[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 256, 256, 14) 0           concatenate_47[0][0]
#                                                                  tf.__operators__.getitem_60[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_61 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 256, 256, 12) 0           concatenate_54[0][0]
#                                                                  tf.__operators__.getitem_68[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_69 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 256, 256, 10) 0           concatenate_61[0][0]
#                                                                  tf.__operators__.getitem_75[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 256, 256, 2)  0           tf.__operators__.getitem_76[0][0]
#                                                                  tf.__operators__.getitem_77[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 256, 256, 8)  0           concatenate_68[0][0]
#                                                                  tf.__operators__.getitem_83[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_84 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 256, 256, 6)  0           concatenate_75[0][0]
#                                                                  tf.__operators__.getitem_91[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_92 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 256, 8,  0           activation[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 256, 256, 8,  0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 8)  0           tf.__operators__.add_2[0][0]
#                                                                  tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 8)  0           tf.__operators__.getitem_11[0][0]
#                                                                  tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_14 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_16 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_17 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_18 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_19 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 16)     272         average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 1, 16)     272         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 16)     0           concatenate_41[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 256, 256, 16) 0           concatenate_48[0][0]
#                                                                  tf.__operators__.getitem_61[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 256, 256, 14) 0           concatenate_55[0][0]
#                                                                  tf.__operators__.getitem_69[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_70 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 256, 256, 12) 0           concatenate_62[0][0]
#                                                                  tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_78 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 256, 256, 10) 0           concatenate_69[0][0]
#                                                                  tf.__operators__.getitem_84[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_85 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_86 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_87 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 256, 256, 8)  0           concatenate_76[0][0]
#                                                                  tf.__operators__.getitem_92[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_93 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 256, 256, 2,  0           reshape[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 256, 256, 2,  0           reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 12) 0           concatenate_4[0][0]
#                                                                  tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 12) 0           concatenate_7[0][0]
#                                                                  tf.__operators__.getitem_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_15 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 8)  0           tf.__operators__.getitem_16[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 256, 256, 4)  0           tf.__operators__.getitem_18[0][0]
#                                                                  tf.__operators__.getitem_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_21 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_22 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 256, 256, 16) 0           concatenate_26[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 256, 256, 16) 0           concatenate_33[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 16)     272         average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 1, 1, 16)     0           concatenate_49[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 256, 256, 16) 0           concatenate_56[0][0]
#                                                                  tf.__operators__.getitem_70[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 256, 256, 14) 0           concatenate_63[0][0]
#                                                                  tf.__operators__.getitem_78[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_79 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 256, 256, 12) 0           concatenate_70[0][0]
#                                                                  tf.__operators__.getitem_85[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 256, 256, 2)  0           tf.__operators__.getitem_86[0][0]
#                                                                  tf.__operators__.getitem_87[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 256, 256, 10) 0           concatenate_77[0][0]
#                                                                  tf.__operators__.getitem_93[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_94 (Sl (None, 256, 256, 2)  0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 256, 256, 8)  0           permute[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 256, 256, 8)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 256, 256, 8)  0           permute[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 256, 256, 8)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 256, 16) 0           concatenate_5[0][0]
#                                                                  tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 256, 16) 0           concatenate_8[0][0]
#                                                                  tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 256, 256, 12) 0           concatenate_11[0][0]
#                                                                  tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_20 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 8)  0           tf.__operators__.getitem_21[0][0]
#                                                                  tf.__operators__.getitem_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_23 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_24 (Sl (None, 256, 256, 4)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_25 (Sl (None, 256, 256, 4)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 256, 256, 32) 0           multiply_8[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 256, 256, 16) 0           concatenate_41[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 16)     272         average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 1, 1, 16)     0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 256, 256, 16) 0           concatenate_64[0][0]
#                                                                  tf.__operators__.getitem_79[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 256, 256, 14) 0           concatenate_71[0][0]
#                                                                  tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_88 (Sl (None, 256, 256, 2)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 256, 256, 12) 0           concatenate_78[0][0]
#                                                                  tf.__operators__.getitem_94[0][0]
# ...
#                                                                  tf.__operators__.add_41[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_29 (AveragePo (None, 1, 1, 64)     0           concatenate_168[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_30 (AveragePo (None, 1, 1, 64)     0           concatenate_169[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 64, 64, 64)   0           concatenate_174[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 64, 64, 64)   0           concatenate_177[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_34 (AveragePo (None, 1, 1, 64)     0           concatenate_185[0][0]
# __________________________________________________________________________________________________
# concatenate_226 (Concatenate)   (None, 64, 64, 320)  0           concatenate_218[0][0]
#                                                                  multiply_46[0][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 64, 64, 64)   0           concatenate_233[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_42 (AveragePo (None, 1, 1, 64)     0           concatenate_249[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_178 (Concatenate)   (None, 64, 64, 128)  0           multiply_37[0][0]
#                                                                  multiply_38[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 64, 64, 64)   0           concatenate_181[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_234 (Concatenate)   (None, 64, 64, 384)  0           concatenate_226[0][0]
#                                                                  multiply_47[0][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 64, 64, 64)   0           concatenate_241[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 1, 1, 64)     4160        average_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 64, 64, 64)   0           concatenate_168[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 64, 64, 64)   0           concatenate_169[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# concatenate_182 (Concatenate)   (None, 64, 64, 192)  0           concatenate_178[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 64, 64, 64)   0           concatenate_185[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_242 (Concatenate)   (None, 64, 64, 448)  0           concatenate_234[0][0]
#                                                                  multiply_48[0][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 64, 64, 64)   0           concatenate_249[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_170 (Concatenate)   (None, 64, 64, 128)  0           multiply_34[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_186 (Concatenate)   (None, 64, 64, 256)  0           concatenate_182[0][0]
#                                                                  multiply_40[0][0]
# __________________________________________________________________________________________________
# concatenate_250 (Concatenate)   (None, 64, 64, 512)  0           concatenate_242[0][0]
#                                                                  multiply_49[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 64)   8256        concatenate_170[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 64, 64, 64)   16448       concatenate_186[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 64, 64, 64)   32832       concatenate_250[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_6 (TFOpLamb (None, 64, 64, 1)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_6 (TFOpLambd (None, 64, 64, 1)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_7 (TFOpLamb (None, 64, 64, 1)    0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_7 (TFOpLambd (None, 64, 64, 1)    0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_8 (TFOpLamb (None, 64, 64, 1)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_8 (TFOpLambd (None, 64, 64, 1)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# concatenate_171 (Concatenate)   (None, 64, 64, 2)    0           tf.math.reduce_mean_6[0][0]
#                                                                  tf.math.reduce_max_6[0][0]
# __________________________________________________________________________________________________
# concatenate_187 (Concatenate)   (None, 64, 64, 2)    0           tf.math.reduce_mean_7[0][0]
#                                                                  tf.math.reduce_max_7[0][0]
# __________________________________________________________________________________________________
# concatenate_251 (Concatenate)   (None, 64, 64, 2)    0           tf.math.reduce_mean_8[0][0]
#                                                                  tf.math.reduce_max_8[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 1)    3           concatenate_171[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 64, 64, 1)    3           concatenate_187[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 64, 1)    3           concatenate_251[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 1)    0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 1)    0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 1)    0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 64, 64, 64)   0           activation_21[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 64, 64, 64)   0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 64, 64, 64)   0           activation_27[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           multiply_36[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64, 64)   0           multiply_41[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 64, 64)   0           multiply_50[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 64)   4160        add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 64, 64)   4160        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 64)   4160        add_18[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           conv2d_60[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 64)   0           conv2d_68[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 64, 64)   0           conv2d_80[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 64)   0           add_17[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 64, 64, 64)   0           activation_23[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           add_20[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            260         global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 340,047
# Trainable params: 339,151
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_acc' , mode='max' ,
                                                  factor = 0.5 , patience = 8 , verbose=1 , cooldown = 1,
                                                 min_delta = 0.0001)

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=30, verbose=1,
                                              mode = 'max', restore_best_weights = True)
check_path = r'ProstgradeNet.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(check_path, monitor = 'val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')


history_1 = model.fit(train_generator , validation_data = validation_generator ,
                                  steps_per_epoch= len(train_generator) ,
                                  validation_steps = len(validation_generator)
                                  ,epochs = 65,callbacks = [reduce_lr, early_stop, checkpoint] )
# Out:
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\keras_preprocessing\image\image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\keras_preprocessing\image\image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/65
# 2921/2921 [==============================] - 696s 232ms/step - loss: 0.7833 - acc: 0.6553 - val_loss: 0.6788 - val_acc: 0.7186
#
# Epoch 00001: val_acc improved from -inf to 0.71864, saving model to ProstgradeNet.h5
# Epoch 2/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.5813 - acc: 0.7385 - val_loss: 0.5446 - val_acc: 0.7547
#
# Epoch 00002: val_acc improved from 0.71864 to 0.75473, saving model to ProstgradeNet.h5
# Epoch 3/65
# 2921/2921 [==============================] - 674s 231ms/step - loss: 0.4963 - acc: 0.7723 - val_loss: 1.6879 - val_acc: 0.4275
#
# Epoch 00003: val_acc did not improve from 0.75473
# Epoch 4/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.4531 - acc: 0.7975 - val_loss: 0.7646 - val_acc: 0.7158
#
# Epoch 00004: val_acc did not improve from 0.75473
# Epoch 5/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.4308 - acc: 0.8077 - val_loss: 1.0430 - val_acc: 0.5564
#
# Epoch 00005: val_acc did not improve from 0.75473
# Epoch 6/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.4031 - acc: 0.8216 - val_loss: 0.5967 - val_acc: 0.7162
#
# Epoch 00006: val_acc did not improve from 0.75473
# Epoch 7/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.3788 - acc: 0.8358 - val_loss: 0.7847 - val_acc: 0.6212
#
# Epoch 00007: val_acc did not improve from 0.75473
# Epoch 8/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.3631 - acc: 0.8436 - val_loss: 0.5740 - val_acc: 0.7726
#
# Epoch 00008: val_acc improved from 0.75473 to 0.77260, saving model to ProstgradeNet.h5
# Epoch 9/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.3392 - acc: 0.8549 - val_loss: 0.5157 - val_acc: 0.7901
#
# Epoch 00009: val_acc improved from 0.77260 to 0.79012, saving model to ProstgradeNet.h5
# Epoch 10/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.3262 - acc: 0.8607 - val_loss: 0.4723 - val_acc: 0.8104
#
# Epoch 00010: val_acc improved from 0.79012 to 0.81044, saving model to ProstgradeNet.h5
# Epoch 11/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.3148 - acc: 0.8673 - val_loss: 0.3745 - val_acc: 0.8504
#
# Epoch 00011: val_acc improved from 0.81044 to 0.85039, saving model to ProstgradeNet.h5
# Epoch 12/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.3007 - acc: 0.8740 - val_loss: 0.5044 - val_acc: 0.8076
#
# Epoch 00012: val_acc did not improve from 0.85039
# Epoch 13/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2892 - acc: 0.8742 - val_loss: 0.4011 - val_acc: 0.8248
#
# Epoch 00013: val_acc did not improve from 0.85039
# Epoch 14/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2811 - acc: 0.8821 - val_loss: 0.4533 - val_acc: 0.8199
#
# Epoch 00014: val_acc did not improve from 0.85039
# Epoch 15/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2747 - acc: 0.8833 - val_loss: 0.4771 - val_acc: 0.8206
#
# Epoch 00015: val_acc did not improve from 0.85039
# Epoch 16/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2663 - acc: 0.8904 - val_loss: 0.5110 - val_acc: 0.8024
#
# Epoch 00016: val_acc did not improve from 0.85039
# Epoch 17/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2572 - acc: 0.8948 - val_loss: 0.4007 - val_acc: 0.8329
#
# Epoch 00017: val_acc did not improve from 0.85039
# Epoch 18/65
# 2921/2921 [==============================] - 679s 232ms/step - loss: 0.2506 - acc: 0.8975 - val_loss: 0.3234 - val_acc: 0.8609
#
# Epoch 00018: val_acc improved from 0.85039 to 0.86090, saving model to ProstgradeNet.h5
# Epoch 19/65
# 2921/2921 [==============================] - 678s 232ms/step - loss: 0.2413 - acc: 0.8997 - val_loss: 0.2723 - val_acc: 0.8942
#
# Epoch 00019: val_acc improved from 0.86090 to 0.89418, saving model to ProstgradeNet.h5
# Epoch 20/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2363 - acc: 0.9009 - val_loss: 0.3510 - val_acc: 0.8605
#
# Epoch 00020: val_acc did not improve from 0.89418
# Epoch 21/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2282 - acc: 0.9029 - val_loss: 0.2389 - val_acc: 0.8963
#
# Epoch 00021: val_acc improved from 0.89418 to 0.89629, saving model to ProstgradeNet.h5
# Epoch 22/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2189 - acc: 0.9110 - val_loss: 0.3440 - val_acc: 0.8591
#
# Epoch 00022: val_acc did not improve from 0.89629
# Epoch 23/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2198 - acc: 0.9109 - val_loss: 0.2578 - val_acc: 0.8896
#
# Epoch 00023: val_acc did not improve from 0.89629
# Epoch 24/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.2087 - acc: 0.9152 - val_loss: 0.2463 - val_acc: 0.8896
#
# Epoch 00024: val_acc did not improve from 0.89629
# Epoch 25/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.2066 - acc: 0.9151 - val_loss: 0.2364 - val_acc: 0.9040
#
# Epoch 00025: val_acc improved from 0.89629 to 0.90399, saving model to ProstgradeNet.h5
# Epoch 26/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1997 - acc: 0.9185 - val_loss: 0.3439 - val_acc: 0.8546
#
# Epoch 00026: val_acc did not improve from 0.90399
# Epoch 27/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1932 - acc: 0.9202 - val_loss: 0.3077 - val_acc: 0.8774
#
# Epoch 00027: val_acc did not improve from 0.90399
# Epoch 28/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1893 - acc: 0.9211 - val_loss: 0.2452 - val_acc: 0.8963
#
# Epoch 00028: val_acc did not improve from 0.90399
# Epoch 29/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1780 - acc: 0.9259 - val_loss: 0.5032 - val_acc: 0.7950
#
# Epoch 00029: val_acc did not improve from 0.90399
# Epoch 30/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1766 - acc: 0.9297 - val_loss: 0.2113 - val_acc: 0.9131
#
# Epoch 00030: val_acc improved from 0.90399 to 0.91310, saving model to ProstgradeNet.h5
# Epoch 31/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.1679 - acc: 0.9320 - val_loss: 0.2894 - val_acc: 0.8900
#
# Epoch 00031: val_acc did not improve from 0.91310
# Epoch 32/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1632 - acc: 0.9345 - val_loss: 0.2334 - val_acc: 0.9089
#
# Epoch 00032: val_acc did not improve from 0.91310
# Epoch 33/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1526 - acc: 0.9374 - val_loss: 1.3436 - val_acc: 0.6093
#
# Epoch 00033: val_acc did not improve from 0.91310
# Epoch 34/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1563 - acc: 0.9379 - val_loss: 0.2349 - val_acc: 0.9071
#
# Epoch 00034: val_acc did not improve from 0.91310
# Epoch 35/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1454 - acc: 0.9403 - val_loss: 0.2177 - val_acc: 0.9068
#
# Epoch 00035: val_acc did not improve from 0.91310
# Epoch 36/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1413 - acc: 0.9453 - val_loss: 0.3362 - val_acc: 0.8753
#
# Epoch 00036: val_acc did not improve from 0.91310
# Epoch 37/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1367 - acc: 0.9445 - val_loss: 0.2429 - val_acc: 0.8998
#
# Epoch 00037: val_acc did not improve from 0.91310
# Epoch 38/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.1293 - acc: 0.9480 - val_loss: 0.2374 - val_acc: 0.9114
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00038: val_acc did not improve from 0.91310
# Epoch 39/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0818 - acc: 0.9686 - val_loss: 0.2652 - val_acc: 0.9100
#
# Epoch 00039: val_acc did not improve from 0.91310
# Epoch 40/65
# 2921/2921 [==============================] - 675s 231ms/step - loss: 0.0718 - acc: 0.9736 - val_loss: 0.2552 - val_acc: 0.9114
#
# Epoch 00040: val_acc did not improve from 0.91310
# Epoch 41/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0675 - acc: 0.9755 - val_loss: 0.2827 - val_acc: 0.9089
#
# Epoch 00041: val_acc did not improve from 0.91310
# Epoch 42/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0615 - acc: 0.9787 - val_loss: 0.2476 - val_acc: 0.9135
#
# Epoch 00042: val_acc improved from 0.91310 to 0.91345, saving model to ProstgradeNet.h5
# Epoch 43/65
# 2921/2921 [==============================] - 677s 232ms/step - loss: 0.0586 - acc: 0.9792 - val_loss: 0.3429 - val_acc: 0.8973
#
# Epoch 00043: val_acc did not improve from 0.91345
# Epoch 44/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0558 - acc: 0.9800 - val_loss: 0.2727 - val_acc: 0.9194
#
# Epoch 00044: val_acc improved from 0.91345 to 0.91941, saving model to ProstgradeNet.h5
# Epoch 45/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0504 - acc: 0.9820 - val_loss: 0.2626 - val_acc: 0.9222
#
# Epoch 00045: val_acc improved from 0.91941 to 0.92221, saving model to ProstgradeNet.h5
# Epoch 46/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0468 - acc: 0.9831 - val_loss: 0.2645 - val_acc: 0.9180
#
# Epoch 00046: val_acc did not improve from 0.92221
# Epoch 47/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0450 - acc: 0.9834 - val_loss: 0.2416 - val_acc: 0.9233
#
# Epoch 00047: val_acc improved from 0.92221 to 0.92327, saving model to ProstgradeNet.h5
# Epoch 48/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0430 - acc: 0.9840 - val_loss: 0.3416 - val_acc: 0.8977
#
# Epoch 00048: val_acc did not improve from 0.92327
# Epoch 49/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0429 - acc: 0.9836 - val_loss: 0.4118 - val_acc: 0.8949
#
# Epoch 00049: val_acc did not improve from 0.92327
# Epoch 50/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0360 - acc: 0.9872 - val_loss: 0.4223 - val_acc: 0.8984
#
# Epoch 00050: val_acc did not improve from 0.92327
# Epoch 51/65
# 2921/2921 [==============================] - 677s 232ms/step - loss: 0.0408 - acc: 0.9849 - val_loss: 0.4465 - val_acc: 0.9064
#
# Epoch 00051: val_acc did not improve from 0.92327
# Epoch 52/65
# 2921/2921 [==============================] - 680s 233ms/step - loss: 0.0325 - acc: 0.9888 - val_loss: 0.3592 - val_acc: 0.9040
#
# Epoch 00052: val_acc did not improve from 0.92327
# Epoch 53/65
# 2921/2921 [==============================] - 677s 232ms/step - loss: 0.0341 - acc: 0.9871 - val_loss: 0.3212 - val_acc: 0.9152
#
# Epoch 00053: val_acc did not improve from 0.92327
# Epoch 54/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0372 - acc: 0.9874 - val_loss: 0.3368 - val_acc: 0.9177
#
# Epoch 00054: val_acc did not improve from 0.92327
# Epoch 55/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0341 - acc: 0.9879 - val_loss: 0.2902 - val_acc: 0.9135
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00055: val_acc did not improve from 0.92327
# Epoch 56/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0170 - acc: 0.9950 - val_loss: 0.3835 - val_acc: 0.9103
#
# Epoch 00056: val_acc did not improve from 0.92327
# Epoch 57/65
# 2921/2921 [==============================] - 677s 232ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.2849 - val_acc: 0.9271
#
# Epoch 00057: val_acc improved from 0.92327 to 0.92712, saving model to ProstgradeNet.h5
# Epoch 58/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0122 - acc: 0.9967 - val_loss: 0.2930 - val_acc: 0.9247
#
# Epoch 00058: val_acc did not improve from 0.92712
# Epoch 59/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0126 - acc: 0.9964 - val_loss: 0.3425 - val_acc: 0.9233
#
# Epoch 00059: val_acc did not improve from 0.92712
# Epoch 60/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0141 - acc: 0.9954 - val_loss: 0.3409 - val_acc: 0.9264
#
# Epoch 00060: val_acc did not improve from 0.92712
# Epoch 61/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0137 - acc: 0.9953 - val_loss: 0.3174 - val_acc: 0.9250
#
# Epoch 00061: val_acc did not improve from 0.92712
# Epoch 62/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0099 - acc: 0.9972 - val_loss: 0.3666 - val_acc: 0.9187
#
# Epoch 00062: val_acc did not improve from 0.92712
# Epoch 63/65
# 2921/2921 [==============================] - 676s 231ms/step - loss: 0.0108 - acc: 0.9973 - val_loss: 0.3335 - val_acc: 0.9156
#
# Epoch 00063: val_acc did not improve from 0.92712
# Epoch 64/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0077 - acc: 0.9976 - val_loss: 0.3376 - val_acc: 0.9257
#
# Epoch 00064: val_acc did not improve from 0.92712
# Epoch 65/65
# 2921/2921 [==============================] - 676s 232ms/step - loss: 0.0114 - acc: 0.9961 - val_loss: 0.3607 - val_acc: 0.9236
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00065: val_acc did not improve from 0.92712

# %%
np.save('ProsGradeNet.npy',history_1.history)

# %%
a=np.load(r'ProsGradeNet.npy',allow_pickle='TRUE').item()
plt.plot(a['acc'] , label = 'train_acc_1st')
plt.plot(a['val_acc'] , label = 'val_acc_1st')
plt.legend()
plt.xlabel("No. of epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")
plt.show()
plt.plot(a['loss'] , label = 'loss_1st')
plt.plot(a['val_loss'] , label = 'val_loss_1st')
plt.legend()
plt.xlabel("No. of epochs")
plt.ylabel("Loss")
plt.title("Loss")
plt.show()

# %%
test_d = ImageDataGenerator(rescale=1. / 255)
test = test_d.flow_from_directory(
    test_dir,
    target_size=(256,256),
    batch_size=1,
    shuffle = False,
    class_mode='categorical')

import numpy as np
test_step = test.n//test.batch_size
test.reset()
pred = model.predict_generator(test , steps = test_step , verbose = 1)
pred_class_indices = np.argmax(pred,axis=1)

print(pred_class_indices)

from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score,jaccard_score,classification_report
from sklearn.metrics import precision_score,recall_score,jaccard_score
classes = [0,1,2,3]


for cl in classes:

    print("class: ",cl)

    a1 = np.uint8(test.labels == cl)
    a2 = np.uint8(pred_class_indices == cl)

    print('Accuracy {}'.format(accuracy_score(y_true=a1, y_pred=a2)))
    print('F1 {}'.format(f1_score(y_true=a1, y_pred=a2)))
    print('precision {}'.format(precision_score(y_true=a1, y_pred=a2)))
    print('recall {}'.format(recall_score(y_true=a1, y_pred=a2)))

    print('jaccard {}'.format(jaccard_score(y_true=a1, y_pred=a2)))
    print("_______________________________")


print('Accuracy {}'.format(accuracy_score(y_true=test.labels, y_pred=pred_class_indices)))
print('F1 {}'.format(f1_score(y_true=test.labels, y_pred=pred_class_indices,average = "macro")))
print('precision {}'.format(precision_score(y_true=test.labels, y_pred=pred_class_indices,average = "macro")))
print('recall {}'.format(recall_score(y_true=test.labels, y_pred=pred_class_indices,average = "macro")))

print('jaccard {}'.format(jaccard_score(y_true=test.labels, y_pred=pred_class_indices,average = "macro")))
print('confusion_matrix\n {}'.format(confusion_matrix(y_true=test.labels, y_pred=pred_class_indices)))
print('classification_report\n {}'.format(classification_report(y_true=test.labels, y_pred=pred_class_indices)))
print('\n\n')
# Out:
# Found 2939 images belonging to 4 classes.
#    8/2939 [..............................] - ETA: 51s
# C:\Users\NITK\anaconda3\envs\Shyam_Lal\lib\site-packages\tensorflow\python\keras\engine\training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 2939/2939 [==============================] - 62s 21ms/step
# [0 0 0 ... 3 3 3]
# class:  0
# Accuracy 0.9407961891799932
# F1 0.8916562889165628
# precision 0.8883374689826302
# recall 0.895
# jaccard 0.8044943820224719
# _______________________________
# class:  1
# Accuracy 0.9193603266417149
# F1 0.8408327736736065
# precision 0.8226018396846255
# recall 0.8598901098901099
# jaccard 0.7253765932792584
# _______________________________
# class:  2
# Accuracy 0.9700578428036747
# F1 0.9369627507163324
# precision 0.9646017699115044
# recall 0.9108635097493036
# jaccard 0.8814016172506739
# _______________________________
# class:  3
# Accuracy 0.9996597482136781
# F1 0.9992790194664743
# precision 0.9985590778097982
# recall 1.0
# jaccard 0.9985590778097982
# _______________________________
# Accuracy 0.9149370534195305
# F1 0.917182708193244
# precision 0.9185250390971397
# recall 0.9164384049098534
# jaccard 0.8524579175905507
# confusion_matrix
#  [[716  78   5   1]
#  [ 83 626  19   0]
#  [  7  57 654   0]
#  [  0   0   0 693]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       800
#            1       0.82      0.86      0.84       728
#            2       0.96      0.91      0.94       718
#            3       1.00      1.00      1.00       693
#
#     accuracy                           0.91      2939
#    macro avg       0.92      0.92      0.92      2939
# weighted avg       0.92      0.91      0.92      2939
